# %%
import networkx as nx
import pandas as pd

import requests, re


# create a word graph (austin)
# use it for simple gen
# create a word graph (carrol)
# use it for simple gen

# %% [markdown]
# # Dictionary of Books (Corpus)
# Let's build our own library of text to work with. We can swap them in and out and see how they affect things, or we could get all of the data and create one combined language model.

# %%
def load_book(title):
    
    url = BOOKS[title]
    
    print("Fetching {}: {}".format(title, url))
    
    return requests.get(url).text

# %%
BOOKS = {
    "pride_and_prejudice":              "https://www.gutenberg.org/cache/epub/1342/pg1342.txt",
    "alice_in_wonderland":              "https://www.gutenberg.org/cache/epub/11/pg11.txt",
    "frankenstein":                     "https://www.gutenberg.org/cache/epub/84/pg84.txt",
    "dracula":                          "https://www.gutenberg.org/cache/epub/345/pg345.txt",
    "a_tale_of_two_cities":             "https://www.gutenberg.org/cache/epub/98/pg98.txt",
    "great_expectations":               "https://www.gutenberg.org/cache/epub/1400/pg1400.txt",
    "adventures_of_huckleberry_finn":   "https://www.gutenberg.org/cache/epub/76/pg76.txt",
    "adventures_of_tom_sawyer":         "https://www.gutenberg.org/cache/epub/74/pg74.txt",
    "war_of_the_worlds":                "https://www.gutenberg.org/cache/epub/36/pg36.txt",
    "the_time_machine":                 "https://www.gutenberg.org/cache/epub/35/pg35.txt",
    "the_picture_of_dorian_gray":       "https://www.gutenberg.org/cache/epub/174/pg174.txt",
    "treasure_island":                  "https://www.gutenberg.org/cache/epub/120/pg120.txt",
    "strange_case_of_dr_jekyll":        "https://www.gutenberg.org/cache/epub/43/pg43.txt",
    "hound_of_the_baskervilles":        "https://www.gutenberg.org/cache/epub/2852/pg2852.txt",
    "adventures_of_sherlock_holmes":    "https://www.gutenberg.org/cache/epub/1661/pg1661.txt",
    "middlemarch":                      "https://www.gutenberg.org/cache/epub/145/pg145.txt",
    "emma":                             "https://www.gutenberg.org/cache/epub/158/pg158.txt",
    "through_the_looking_glass":        "https://www.gutenberg.org/cache/epub/12/pg12.txt",
    "the_invisible_man":                "https://www.gutenberg.org/cache/epub/5230/pg5230.txt",
    "a_christmas_carol":                "https://www.gutenberg.org/cache/epub/46/pg46.txt",
}

# Claude populated this list; i have only confirmed what I have shown

# %%
text = load_book("alice_in_wonderland")
# Out:
# Fetching alice_in_wonderland: https://www.gutenberg.org/cache/epub/11/pg11.txt

# %%
print(text)
# Out:
# ﻿The Project Gutenberg eBook of Alice's Adventures in Wonderland
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Alice's Adventures in Wonderland
#
# Author: Lewis Carroll
#
#
#
# Release date: June 27, 2008 [eBook #11]
#                 Most recently updated: June 26, 2025
#
# Language: English
#
# Other information and formats: www.gutenberg.org/ebooks/11
#
# Credits: Arthur DiBianca and David Widger
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK ALICE'S ADVENTURES IN WONDERLAND ***
#
# [Illustration]
#
#
#
#
# Alice’s Adventures in Wonderland
#
# by Lewis Carroll
#
# ...

# %% [markdown]
# # strip every non-word or space
#
# I want to create a word graph, so... I only want words.

# %%
def clean_text(text):
    
    return re.sub(r'[^a-zA-Z\s\-']', '', text)
# Out:
#   Cell In[44], line 3
#     return re.sub(r'[^a-zA-Z\s\-']', '', text)
#                                  ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
text = clean_text(text)
print(text)
# Out:
# The Project Gutenberg eBook of Alices Adventures in Wonderland
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever You may copy it give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online
# at wwwgutenbergorg If you are not located in the United States
# you will have to check the laws of the country where you are located
# before using this eBook
#
# Title Alices Adventures in Wonderland
#
# Author Lewis Carroll
#
#
#
# Release date June   eBook
#                 Most recently updated June
#
# Language English
#
# Other information and formats wwwgutenbergorgebooks
#
# Credits Arthur DiBianca and David Widger
#
#
#  START OF THE PROJECT GUTENBERG EBOOK ALICES ADVENTURES IN WONDERLAND
#
# Illustration
#
#
#
#
# Alices Adventures in Wonderland
#
# by Lewis Carroll
#
# THE MILLENNIUM FULCRUM EDITION
#
# Contents
#
# ...

# %% [markdown]
# # tokenize the text

# %%
tokens = text.split() # ultra simplistic tokenization
tokens
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Alices',
#  'Adventures',
#  'in',
#  'Wonderland',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  'You',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'wwwgutenbergorg',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
#  'located',
# ...

# %% [markdown]
# # create the edges
#
# start at the start, and capture the word links

# %%
edgelist = []

for i in range(len(tokens) - 1):

    t1 = tokens[i]
    t2 = tokens[i+1]
    
    edge = (t1, t2)
    
    edgelist.append(edge)
    
edgelist
# Out:
# [('The', 'Project'),
#  ('Project', 'Gutenberg'),
#  ('Gutenberg', 'eBook'),
#  ('eBook', 'of'),
#  ('of', 'Alices'),
#  ('Alices', 'Adventures'),
#  ('Adventures', 'in'),
#  ('in', 'Wonderland'),
#  ('Wonderland', 'This'),
#  ('This', 'eBook'),
#  ('eBook', 'is'),
#  ('is', 'for'),
#  ('for', 'the'),
#  ('the', 'use'),
#  ('use', 'of'),
#  ('of', 'anyone'),
#  ('anyone', 'anywhere'),
#  ('anywhere', 'in'),
#  ('in', 'the'),
#  ('the', 'United'),
#  ('United', 'States'),
#  ('States', 'and'),
#  ('and', 'most'),
#  ('most', 'other'),
#  ('other', 'parts'),
#  ('parts', 'of'),
#  ('of', 'the'),
#  ('the', 'world'),
#  ('world', 'at'),
#  ('at', 'no'),
#  ('no', 'cost'),
#  ('cost', 'and'),
#  ('and', 'with'),
#  ('with', 'almost'),
#  ('almost', 'no'),
#  ('no', 'restrictions'),
#  ('restrictions', 'whatsoever'),
#  ('whatsoever', 'You'),
#  ('You', 'may'),
#  ('may', 'copy'),
#  ('copy', 'it'),
#  ('it', 'give'),
#  ('give', 'it'),
#  ('it', 'away'),
#  ('away', 'or'),
# ...

# %% [markdown]
# # count the edges

# %%
edgelist_df = pd.DataFrame(edgelist)

edgelist_df.columns = ['w1', 'w2']
edgelist_df['w1'] = edgelist_df['w1'].str.lower() # lowercase words
edgelist_df['w2'] = edgelist_df['w2'].str.lower() # lowercase words
edgelist_df = edgelist_df.groupby(['w1', 'w2']).size().reset_index(name='count') # count links/edges
edgelist_df = edgelist_df[(edgelist_df['w1'].str.len() > 1) & (edgelist_df['w2'].str.len() > 1)] # drop junk

edgelist_df.head()
# Out:
#           w1       w2  count
# 348  a-piece      all      1
# 349    abide       by      1
# 350    abide  figures      1
# 353    about    again      1
# 354    about    among      1

# %%
outfile = 'data/wordgraph/alice_wordgraph.csv'

edgelist_df.to_csv(outfile, index=False, header=True)

# %%
# calculate the probabilities

# %%
# use the word graph
