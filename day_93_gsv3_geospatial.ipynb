# %%
#!pip install folium

# %%
import osmnx as ox
import matplotlib.pyplot as plt

import folium

# %% [markdown]
# # Businesses Near One Business
# This is old code from 2025 when I was first experimenting with GrooveSeeker data. Let's use it as a baseline and then make something useful.

# %%
address = '2724 E Burnside St, Portland, OR 97214' # Rose City Guitar Company

# %%
location = ox.geocode(address)
print(f"Coordinates: {location}")
# Out:
# Coordinates: (45.5227479, -122.6377033)

# %%
max_distance = 1000

tags = {
    'amenity': True,  # Gets ALL amenities
    'shop': True,     # Gets ALL shops
    'tourism': True,  # Gets ALL tourism
    'leisure': True   # Gets ALL leisure
}

businesses = ox.features_from_address(address, tags, dist=max_distance)
businesses_filtered = businesses.dropna(subset=['name'])

print("Found {} businesses within {}m".format(len(businesses_filtered), max_distance))

for idx, row in businesses_filtered.iterrows():

    print()
    print("NAME: {}".format(row.get('name', 'Unknown')))
    
    # Check for amenity, shop, tourism, or leisure type
    entity_type = row.get('amenity') or row.get('shop') or row.get('tourism') or row.get('leisure')
    if entity_type and str(entity_type) != 'nan':
        print("Type: {}".format(entity_type))
    
    street = row.get('addr:street')
    number = row.get('addr:housenumber')
    if street and str(street) != 'nan' and number and str(number) != 'nan':
        print("Address: {} {}".format(number, street))
    elif street and str(street) != 'nan':
        print("Address: {}".format(street))
    
    cuisine = row.get('cuisine')
    if cuisine and str(cuisine) != 'nan':
        print("Cuisine: {}".format(cuisine))
    
    phone = row.get('phone')
    if phone and str(phone) != 'nan':
        print("Phone: {}".format(phone))
# Out:
# Found 315 businesses within 1000m
#
# NAME: Kerr Youth Center at Wynne Watts School
# Type: school
# Address: 424 Northeast 22nd Avenue
#
# NAME: Aquarian Foundation
# Type: place_of_worship
# Address: 321 Northeast 20th Avenue
#
# NAME: Puff Coffee
# Type: cafe
# Address: 2816 Southeast Stark Street
# Cuisine: coffee_shop
# Phone: +1-503-719-9059
#
# NAME: Stark Street Quick Stop Market
# Address: 2816 Southeast Stark Street
#
# NAME: Big Town Hero
# Type: fast_food
# Cuisine: sandwich
#
# NAME: Goodfoot Pub & Lounge
# Type: pub
# Address: 2845 Southeast Stark Street
#
# NAME: Pambiche
# Type: restaurant
# Address: 2811 Northeast Glisan Street
# Cuisine: cuban
# Phone: +1-503-233-0511
#
# NAME: Eastburn
# Type: pub
# Address: 1800 East Burnside Street
# Cuisine: american
#
# NAME: Dove Vivi
# Type: restaurant
# Address: 2727 Northeast Glisan Street
# Cuisine: pizza
# Phone: +1-503-239-4444
#
# NAME: 28th Food Mart
# Address: 2731 Northeast Glisan Street
#
# NAME: Oregonians Credit Union
# Type: bank
# Address: 336 Northeast 20th Avenue
#
# NAME: Laughing Planet
# Type: fast_food
# Address: 3320 Southeast Belmont Street
# Cuisine: mexican
# Phone: +1-503-235-6472
#
# NAME: Avalon Theatre
# Type: cinema
# Address: 3451 Southeast Belmont Street
#
# NAME: Buckman Pool
#
# NAME: A-1 Cleaners
# Address: 2715 Northeast Glisan Street
#
# NAME: Southeast Portland Tool Library
# Type: tool_library
# Address: 1137 Southeast 20th Avenue
#
# NAME: Slide Inn
# Type: restaurant
# Address: 2348 Southeast Ankeny Street
# Cuisine: bavarian
#
# NAME: Bamboo Sushi
# Type: restaurant
# Address: 310 Southeast 28th Avenue
# Cuisine: japanese
#
# NAME: Pix Patisserie / Bar Vivant
# Type: restaurant
#
# NAME: Jade Lounge
# Type: bar
#
# NAME: No Preference
# Type: cafe
# Address: 2327 East Burnside Street
# Cuisine: coffee_shop
# Phone: +15034846903
#
# NAME: Ken's Artisan Pizza
# Type: restaurant
# Address: 304 Southeast 28th Avenue
# Cuisine: pizza
# Phone: +1 503-517-9951
#
# NAME: Wolfsbane Tattoo Collective
# Address: 3640 Southeast Belmont Street
# Phone: +1-971-349-0728
#
# NAME: Bonfire Lounge
# Type: bar
# Address: 2821 Southeast Stark Street
#
# NAME: Baby Doll Pizza
# Type: restaurant
# Address: 2835 Southeast Stark Street
# Cuisine: pizza
#
# NAME: PaaDee
# Type: restaurant
# Address: 6 Southeast 28th Avenue
# Cuisine: thai
# Phone: +1-503-360-1453
#
# NAME: Mattress Lot
# Address: 2406 Northeast Sandy Boulevard
#
# NAME: PDX Natural Access Dispensary
#
# NAME: Hoda's Middle Eastern Cuisine
# Type: restaurant
# Address: 3401 Southeast Belmont Street
# Cuisine: lebanese;mediterranean
# Phone: +1-503-236-8325
#
# NAME: Heart
# Type: cafe
# Address: 2211 East Burnside Street
# Cuisine: coffee;pastry
# Phone: +1-503-235-8276
#
# NAME: Freebie Box (Take one, give one)
# Type: give_box
#
# NAME: Cheese & Crack Snack Shop
# Type: restaurant
# Address: 22 Southeast 28th Avenue
#
# NAME: Optic
# Address: 12 Southeast 28th Avenue
#
# NAME: Starbucks
# Type: cafe
# Address: 2803 East Burnside Street
# Cuisine: coffee_shop
# Phone: +1 503-238-1408
#
# NAME: GRANA Pizza Napoletana
# Type: restaurant
# Address: 2811 East Burnside Street
# Cuisine: pizza
# Phone: +15039543193
#
# NAME: Navarre
# Type: restaurant
# Address: 10 Northeast 28th Avenue
# Cuisine: tapas;european
#
# NAME: Angelface
# Type: bar
# Address: 14 Northeast 28th Avenue
#
# NAME: Too Soon
# Type: bar
#
# NAME: Wooptido
# Address: 24 Northeast 28th Avenue
#
# NAME: La Buca
# Type: restaurant
# Address: 40 Northeast 28th Avenue
# Cuisine: italian
#
# NAME: Vino
# Address: 137 Southeast 28th Avenue
#
# NAME: ZoomCare
# Type: clinic
# Address: 2400 East Burnside Street
#
# NAME: Cedar Mountain Drums
# Address: 2237 East Burnside Street
#
# NAME: Pie Spot
# Address: 521 Northeast 24th Avenue
#
# NAME: Entrust Hair
# Address: 2306 Northeast Glisan Street
#
# NAME: Boxcar Pizza
# Type: restaurant
# Address: 2701 Northeast Sandy Boulevard
# Cuisine: pizza
#
# NAME: EyeCandy
# Address: 2731 Northeast Sandy Boulevard
#
# NAME: Basilisk
# Type: restaurant
# Address: 820 Northeast 27th Avenue
# Cuisine: fried_chicken
# Phone: +1-503-234-7151
#
# NAME: Tusk
# Type: restaurant
# Address: 2448 East Burnside Street
#
# NAME: Jersey Mike's Subs
# Type: fast_food
# Address: 2605 East Burnside Street
# Cuisine: sandwich
#
# NAME: Landfill Rescue Unit
# Address: 2533 Southeast Belmont Street
# Phone: +1-503-679-8579
#
# NAME: Naked City
# Address: 2701 Southeast Belmont Street
#
# NAME: Luke's Frame Shop
# Address: 2707 Southeast Belmont Street
#
# NAME: La Patroncita
# Type: restaurant
# Address: 2832 Southeast Belmont Street
# Cuisine: mexican
# Phone: +1-971-254-4317
#
# NAME: Cowgirl Tattoo
# Address: 3001 Southeast Belmont Street
#
# NAME: Cricket Cafe
# Type: restaurant
# Address: 3159 Southeast Belmont Street
# Cuisine: breakfast;brunch
# Phone: +1-503-235-9348
#
# NAME: Chelsea Salon
# Address: 2121 Southeast Belmont Street
#
# NAME: Plaid Pantry
# Address: 11 Southeast 20th Avenue
#
# NAME: VN Urban
# Type: restaurant
# Address: 2137 East Burnside Street
#
# NAME: Luce
# Type: restaurant
# Address: 2140 East Burnside Street
#
# NAME: 24th & Meatball
# Type: restaurant
# Address: 2341 Northeast Glisan Street
# Cuisine: italian
# Phone: +15032822557
#
# NAME: Church
# Type: bar
#
# NAME: Fire on the Mountain
# Type: restaurant
# Address: 1708 East Burnside Street
# Cuisine: wings
#
# NAME: Nate's Oatmeal Cookies
# Address: 3308 Southeast Belmont Street
#
# NAME: The Midnight Society
# Type: bar
# Address: 3341 Southeast Belmont Street
#
# NAME: Bangkok Belly
# Type: restaurant
# Address: 3342 Southeast Belmont Street
# Cuisine: thai
#
# NAME: Aalto Lounge
# Type: bar
# Address: 3356 Southeast Belmont Street
# Phone: +1-503-235-6041
#
# NAME: Taquería Los Puñales
# Type: restaurant
# Address: 3312 Southeast Belmont Street
# Cuisine: mexican
# Phone: +1-503-206-7233
#
# NAME: Bar Loon
# Type: restaurant
# Address: 3326 Southeast Belmont Street
# Cuisine: regional;american;seafood;burger;pasta;salad;dessert
#
# NAME: Straight From New York Pizza
# Type: restaurant
# Address: 3330 Southeast Belmont Street
# Cuisine: pizza
# Phone: +1-503-736-9739
#
# NAME: The Circuit Northeast
# Address: 410 Northeast 17th Avenue
#
# NAME: Tropicale
# Type: restaurant
# Address: 2337 Northeast Glisan Street
#
# NAME: Providore Fine Foods
# Address: 2340 Northeast Sandy Boulevard
#
# NAME: Arrosto
# Type: fast_food
# Cuisine: chicken
#
# NAME: Oblique Coffee Roasters
# Type: cafe
# Address: 3039 Southeast Stark Street
# Cuisine: coffee_shop
#
# NAME: Seven Virtues Coffee
# Type: cafe
# Address: 2737 Northeast Sandy Boulevard
# Cuisine: coffee_shop
#
# NAME: Han Oak
# Type: restaurant
# Address: 511 Northeast 24th Avenue
# Cuisine: korean
#
# NAME: Davenport
# Type: restaurant
# Address: 2215 East Burnside Street
#
# NAME: Missionary Chocolates
# Address: 2712 Northeast Glisan Street
#
# NAME: Edible Arrangements
# Address: 2710 Northeast Glisan Street
# Phone: +1-503-236-3395
#
# NAME: Nomad.pdx
# Type: restaurant
#
# NAME: Made You Look
# Address: 2418 East Burnside Street
# Phone: +1 503 719 7906
#
# NAME: Enhance Salon
# Address: 2414 East Burnside Street
# Phone: +1 503 232 3186
#
# NAME: One Drop Bottle Shop
# Address: 2410 East Burnside Street
#
# NAME: The 12th Fret
# Address: 2402 Southeast Belmont Street
# Phone: +15032311912
#
# NAME: Portland Knife House
# Address: 2637 Southeast Belmont Street
#
# NAME: Bluto's
# Type: restaurant
# Address: 2838 Southeast Belmont Street
# Cuisine: greek
# Phone: +1-971-383-1619
#
# NAME: Bare Bones Cafe & Bar
# Type: restaurant
# Address: 2900 Southeast Belmont Street
#
# NAME: Mortal Emblem
# Address: 3333 Southeast Belmont Street
# Phone: +1-503-349-7813
#
# NAME: Belmont Inn
# Type: bar
# Address: 3357 Southeast Belmont Street
# Phone: +1-503-232-1998
#
# NAME: The Side Street Tavern
# Type: bar
# Address: 828 Southeast 34th Avenue
# Phone: +1-503-236-7999
#
# NAME: The Green Microgym-Belmont
# Address: 828 Southeast 34th Avenue
#
# NAME: Mad Greek Deli
# Type: restaurant
# Address: 1740 East Burnside Street
# Cuisine: greek
# Phone: +1 503 232 0274
#
# NAME: Tight Tacos
# Type: restaurant
# Address: 2707 Northeast Sandy Boulevard
#
# NAME: Sari Ramyun
# Type: restaurant
# Address: 2713 Northeast Sandy Boulevard
#
# NAME: Blue Diamond Bar & Grill
# Type: bar
# Address: 2016 Northeast Sandy Boulevard
# Phone: +1-503-230-9590
#
# NAME: Nova Coffee
# Type: cafe
# Address: 610 Northeast 20th Avenue
#
# NAME: Olé Olé
# Type: restaurant
# Address: 2137 East Burnside Street
# Cuisine: mexican
#
# NAME: Paydirt
# Type: bar
# Address: 2724 Northeast Pacific Street
#
# NAME: Sugar Hill
# Type: bar
# Address: 3348 Southeast Belmont Street
#
# NAME: Epif
# Type: restaurant
# Address: 410 Northeast 28th Avenue
#
# NAME: Parallel PDX
# Type: restaurant
# Address: 3101 Northeast Sandy Boulevard
# Phone: +1-503-327-8806
#
# NAME: The Vern
# Type: bar
# Address: 2622 Southeast Belmont Street
# Phone: +1-503-233-7851
#
# NAME: Old Pal
# Type: restaurant
# Address: 3350 Southeast Morrison Street
# Cuisine: seafood;regional;salad;dessert;sandwich
# Phone: +1-503-477-9663
#
# NAME: India Oven
# Type: restaurant
# Address: 3450 Southeast Belmont Street
# Cuisine: indian
# Phone: +1-971-865-5973
#
# NAME: Khun Pic's Bahn Thai
# Type: restaurant
# Address: 3429 Southeast Belmont Street
# Cuisine: thai
#
# NAME: One Moto Cafe
# Type: cafe
# Address: 1642 Northeast Sandy Boulevard
# Phone: +1 503 894 9566
#
# NAME: Triple Nickel Pub
# Type: pub
# Address: 3646 Southeast Belmont Street
#
# NAME: Rollin Fresh
# Type: restaurant
# Address: 2329 Northeast Glisan Street
# Phone: +19713862110
#
# NAME: Cream
# Address: 2730 East Burnside Street
#
# NAME: Heritage Barbershop
# Address: 2137 East Burnside Street
#
# NAME: Stitch In A Hurry
#
# NAME: Healing Hands Massage & Bodywork
# Address: 2304 East Burnside Street
#
# NAME: Meat for Cats and Dogs
# Address: 2244 East Burnside Street
#
# NAME: Appetite Shop
# Address: 2136 East Burnside Street
#
# NAME: Datura
# Address: 1847 East Burnside Street
#
# NAME: Future Dreams Books
# Address: 1847 East Burnside Street
#
# NAME: Future Shock
# Address: 1914 East Burnside Street
#
# NAME: The Whole 9 Yards
# Address: 1820 East Burnside Street
#
# NAME: Fix Auto
# Address: 1722 East Burnside Street
#
# NAME: Fortune Tattoo
# Address: 1716 East Burnside Street
#
# NAME: Columbia Art & Drafting Supply
# Address: 1515 East Burnside Street
# Phone: +1-503-232-2216
#
# NAME: The Salvation Army Rose Center for Seniors
# Type: social_facility
# Address: 211 Northeast 18th Avenue
#
# NAME: Boyd Motor Werks
# Address: 224 Northeast 18th Avenue
#
# NAME: Pro Tek Automotive
# Address: 1625 Northeast Sandy Boulevard
#
# NAME: The Children's Gym
# Address: 1625 Northeast Sandy Boulevard
#
# NAME: Rosenstadt Brewery
# Type: pub
# Address: 2117 Northeast Oregon Street
#
# NAME: Sidestreet Arts
# Address: 140 Southeast 28th Avenue
#
# NAME: Soro Soro
# Type: cafe
# Address: 2250 East Burnside Street
#
# NAME: Halo Salon
# Address: 2000 Northeast Sandy Boulevard
#
# NAME: Dream Cakes
# Address: 2450 Northeast Sandy Boulevard
#
# NAME: Dava Bead & Trade
# Address: 2470 Northeast Sandy Boulevard
#
# NAME: Project Object
# Address: 2502 Northeast Sandy Boulevard
#
# NAME: Leeward
# Address: 2504 Northeast Sandy Boulevard
#
# NAME: Make & Mary
# Address: 2506 Northeast Sandy Boulevard
#
# NAME: Fomo Chicken
# Type: fast_food
# Address: 113 Southeast 28th Avenue
# Cuisine: chicken;korean
# Phone: +1-503-308-0258
#
# NAME: Mountain Shop
# Address: 1205 Northeast 33rd Avenue
# Phone: +1-503-288-6768
#
# NAME: Futel
# Type: telephone
# Address: 2333 Southeast Taylor Street
# Phone: +1-503-926-6271
#
# NAME: Fantasy Hollywood
# Address: 3137 Northeast Sandy Boulevard
# Phone: +1-503-239-6969
#
# NAME: Kelz Beauty & Barbershop
# Address: 3121 Northeast Sandy Boulevard
# Phone: +1-971-344-6719
#
# NAME: Amazon Locker
# Type: parcel_locker
#
# NAME: Miami Nice
# Type: restaurant
# Address: 2117 Northeast Oregon Street
# Cuisine: american;cuban
# Phone: +1 818 200 5571
#
# NAME: Sammich
# Type: fast_food
# Address: 2137 east burnside street
#
# NAME: Hellenic-American Cultural Center & Museum
# Address: 3131 Northeast Glisan Street
# Phone: +1 503-858-8567
#
# NAME: TAP Plastics
# Address: 2842 Northeast Sandy Boulevard
# Phone: +1-503-230-0770
#
# NAME: Annam VL
# Type: restaurant
# Address: 3336 Southeast Belmont Street
# Cuisine: vietnamese
#
# NAME: Captured Beer Bus
# Type: biergarten
# Address: 113 Southeast 28th Avenue
#
# NAME: Airlink
# Address: 1926 Northeast Sandy Boulevard
#
# NAME: Bearded Lady Electrology, llc
# Address: 3347 Southeast Belmont Street
# Phone: +1-503-999-9492
#
# NAME: Biketown
# Type: bicycle_rental
#
# NAME: Staccato Gelato
# Type: ice_cream
# Address: 232 Northeast 28th Avenue
#
# NAME: Mikiko Mochi Donuts
# Type: cafe
# Address: 300 Northeast 28th Avenue
# Cuisine: donut
#
# NAME: Concrete Treehouse Salon
# Address: 320 Northeast 28th Avenue
#
# NAME: Montelupo Italian Market
# Type: restaurant
# Address: 344 Northeast 28th Avenue
#
# NAME: Friendship Kitchen
# Type: restaurant
# Address: 2333 Northeast Glisan Street
# Phone: +15032068441
#
# NAME: Lolo Pass
# Address: 1616 East Burnside Street
#
# NAME: Picnic Area E
#
# NAME: Roux Boi
# Type: restaurant
# Address: 2349 Southeast Ankeny Street
#
# NAME: Brassworks Gallery
#
# NAME: HUG
#
# NAME: Pairings Portland Wine Shop & Bar
# Address: 455 Northeast 24th Avenue
# Phone: +15415317653
#
# NAME: ANIKS
# Type: restaurant
# Address: 510 Northeast 28th Avenue
#
# NAME: ChildRoots Southeast Center
# Type: kindergarten
# Address: 50 Southeast 17th Avenue
#
# NAME: Mirisata
# Type: restaurant
# Address: 2420 Southeast Belmont Street
# Phone: +15032334675
#
# NAME: Home Grown Apothecary
# Address: 1937 Northeast Pacific Street
#
# NAME: Saint Burrito
# Type: fast_food
# Cuisine: mexican
#
# NAME: Egyptian Bros
# Type: restaurant
# Cuisine: arab;shawarma
#
# NAME: Afterglow Yoga Portland
#
# NAME: Belmont Books
# Address: 3415 Southeast Belmont Street
# Phone: +1-503-236-0437
#
# NAME: Everett House
# Address: 2927 Northeast Everett Street
#
# NAME: Dear Sandy
# Type: bar
#
# NAME: Henry Higgins Boiled Bagels
# Type: cafe
# Address: 523 Northeast 19th Avenue
# Cuisine: bagel
#
# NAME: Rae Loft
# Type: events_venue
# Address: 2222 Northeast Oregon Street
# Phone: +1 503 893-8177
#
# NAME: Eris Cocktail Lounge
# Type: bar
# Address: 817 Southeast 34th Avenue
#
# NAME: Tantrum Vintage
# Address: 3352 Southeast Belmont Street
# Phone: +1-503-995-9035
#
# NAME: El Chilito Loco
# Type: fast_food
# Address: 3423 Southeast Belmont Street
# Cuisine: mexican
# Phone: +1-503-386-1537
#
# NAME: Quantum Martial Arts
# Address: 2940 Southeast Belmont Street
#
# NAME: Two Rivers Aikido
# Address: 2950 Southeast Belmont Street
#
# NAME: Traditional Taekwon-do
# Address: 2940 Southeast Belmont Street
#
# NAME: Propaganda The Salon
# Address: 821 Southeast 34th Avenue
# Phone: +1-503-231-7646
#
# NAME: High Low Art Space
# Address: 936 Southeast 34th Avenue
#
# NAME: Foxtrot
# Type: bar
# Address: 3244 Southeast Belmont Street
#
# NAME: Anansi Beat
# Address: 3409 Southeast Belmont Street
# Phone: +1-503-236-8283
#
# NAME: Old Friends
# Type: cafe
# Address: 2502 Southeast Belmont Street
# Cuisine: coffee_shop
#
# NAME: Congregation Shir Tikvah
# Type: place_of_worship
# Address: 2420 Northeast Sandy Boulevard
# Phone: +1-503-473-8227
#
# NAME: Triad
#
# NAME: Picnic Area F
#
# NAME: Picnic Area C
#
# NAME: Picnic Area B
#
# NAME: Picnic Area A
#
# NAME: Salvage Goods
# Address: 1506 Northeast Couch Street
#
# NAME: Sunnyside Environmental School
# Type: school
# Address: 3421 Southeast Salmon Street
# Phone: +1-503-916-6226
#
# NAME: Regal Cinemas Lloyd Center 10 & IMAX
# Type: cinema
# Address: 1510 Northeast Multnomah Street
#
# NAME: Holladay Park Plaza
# Type: social_facility
# Address: 1300 room 6B Northeast 16th Avenue
#
# NAME: King Harvest Natural Foods
# Type: restaurant
# Address: 1502 Southeast Morrison Street
#
# NAME: Colonel Summers Park
#
# NAME: Laurelhurst Park
#
# NAME: Central Catholic High School
# Type: school
# Address: 2401 Southeast Stark Street
# Phone: +1 503-235-3138
#
# NAME: Oregon Park
#
# NAME: Moonshot Tavern
# Type: restaurant
# Address: 2725 Southeast Ankeny Street
# Cuisine: creole
#
# NAME: Holman's
# Type: bar
# Address: 15 Southeast 28th Avenue
#
# NAME: Artemisia
# Address: 110 Southeast 28th Avenue
#
# NAME: Crema
# Type: cafe
# Address: 2728 Southeast Ankeny Street
# Cuisine: coffee_shop
#
# NAME: Whole Foods Market
# Address: 2825 East Burnside Street
# Phone: +1 503-232-6601
#
# NAME: Franks-A-Lot
# Type: fast_food
# Cuisine: american
#
# NAME: Laurelhurst Theater
# Type: cinema
# Address: 2735 East Burnside Street
# Phone: +1-503-232-5511
#
# NAME: Voodoo Doughnut
# Type: fast_food
# Address: 1501 Northeast Davis Street
# Cuisine: donut
# Phone: +15032352666
#
# NAME: Hollywood Vintage
# Address: 2757 Northeast Pacific Street
# Phone: +1-503-233-1890
#
# NAME: Consolidated Federal Credit Union
# Type: bank
# Address: 2021 Northeast Sandy Boulevard
#
# NAME: Eastside Jewish Commons
# Type: community_centre
# Address: 2420 Northeast Sandy Boulevard
# Phone: +1-503-208-5425
#
# NAME: The Tree House Collective (THC)
# Address: 2419 Northeast Sandy Boulevard
#
# NAME: Public Storage
# Address: 1620 Northeast Sandy Boulevard
#
# NAME: Lemongrass Thai
# Type: restaurant
# Address: 1705 Northeast Couch Street
# Cuisine: thai
#
# NAME: Pho Gia
# Type: restaurant
# Address: 1944 Northeast Sandy Boulevard
# Cuisine: vietnamese
#
# NAME: Silver Lining Jewerly & Loan
# Address: 2140 Northeast Sandy Boulevard
#
# NAME: First Church of Christ, Scientist, Portland
# Type: place_of_worship
# Address: 2251 Northeast Glisan Street
# Phone: +1-971-291-7797
#
# NAME: Brake Systems Inc.
# Address: 2223 Northeast Sandy Boulevard
#
# NAME: KATU
# Type: studio
# Address: 2153 Northeast Sandy Boulevard
#
# NAME: Nichiren Buddhist Temple of Portland
# Type: place_of_worship
# Address: 2025 Southeast Yamhill Street
#
# NAME: Khora Coffeehouse
# Type: cafe
# Address: 15 Northeast 18th Avenue
#
# NAME: Wagner Dental Care
# Type: dentist
# Address: 1715 East Burnside Street
#
# NAME: Plaid Pantry
# Address: 2730 Northeast Glisan Street
#
# NAME: Migration Brewing
# Type: bar
# Address: 2828 Northeast Glisan Street
#
# NAME: Harp
# Address: 2926 Northeast Flanders Street
#
# NAME: Rudy's Barbershop
# Address: 210 Northeast 28th Avenue
# Phone: +1-503-235-2770
#
# NAME: Guero
# Type: restaurant
# Address: 200 Northeast 28th Avenue
# Cuisine: mexican
#
# NAME: City State Diner
# Type: restaurant
# Address: 128 Northeast 28th Avenue
# Cuisine: american
#
# NAME: Beulahland
# Type: pub
# Address: 118 Northeast 28th Avenue
#
# NAME: Bull Run Pizza
# Type: restaurant
# Address: 108 Northeast 28th Avenue
# Cuisine: pizza
# Phone: +1-971-279-5626
#
# NAME: LaurelThirst Public House
# Type: pub
# Address: 2958 Northeast Glisan Street
#
# NAME: Pollo Norte
# Type: restaurant
# Address: 2935 Northeast Glisan Street
# Phone: +1-503-477-7779
#
# NAME: Tiny Digs
# Address: 2646 Northeast Glisan Street
# Phone: +1-503-406-2944
#
# NAME: The Zipper
# Type: food_court
# Address: 2705 Northeast Sandy Boulevard
#
# NAME: Han Oak
#
# NAME: Enterprise
# Type: car_rental
# Address: 2740 Northeast Sandy Boulevard
#
# NAME: Everett Community Garden
#
# NAME: Buckman Elementary School
# Type: school
# Address: 320 Southeast 16th Avenue
# Phone: +1 503 916 6230
#
# NAME: Kerr Thrift Shop
# Address: 2307 Northeast Flanders Street
#
# NAME: Sunnyside School Park
#
# NAME: AHEPA Mount Hood Chapter 154
# Type: social_centre
#
# NAME: Dave's Hot Chicken
# Type: fast_food
# Address: 2920 Northeast Sandy Boulevard
# Cuisine: chicken
# Phone: +1-503-388-3855
#
# NAME: Stone Tower Seventh Day Adventist Church
# Type: place_of_worship
# Address: 3010 Northeast Holladay Street
# Phone: +1-503-232-6018
#
# NAME: Immanuel Christian Fellowship
# Type: place_of_worship
# Address: 909 Northeast 30th Avenue
#
# NAME: Les Schwab Tire Center
# Address: 2952 Northeast Sandy Boulevard
#
# NAME: Holy Trinity Greek Orthodox Church
# Type: place_of_worship
# Address: 3131 Northeast Glisan Street
# Phone: +1-503-234-0468
#
# NAME: Pet Samaritan Clinic
# Type: veterinary
# Address: 2519 East Burnside Street
#
# NAME: Pacific Crest Community School
# Type: school
# Address: 116 Northeast 29th Avenue
#
# NAME: da Vinci Arts Middle School
# Type: school
# Address: 2508 Northeast Everett Street
# Phone: +1 503 916 5356
#
# NAME: Buckman Field
#
# NAME: Ankeny Tap & Table
# Type: restaurant
# Address: 2724 Southeast Ankeny Street
# Cuisine: pub
# Phone: +1 503 946 1898
#
# NAME: H Mart
# Address: 3301 Southeast Belmont Street
# Cuisine: asian
# Phone: +1 971-407-3167
#
# NAME: Jiffy Lube
# Address: 3240 Northeast Sandy Boulevard
#
# NAME: Presbyterian Church of Laurelhurst
# Type: place_of_worship
# Address: 935 Northeast 33rd Avenue
#
# NAME: India Grill
# Type: restaurant
# Address: 2924 East Burnside Street
# Cuisine: indian
#
# NAME: Laurelhurst Market
# Type: restaurant
# Address: 3155 East Burnside Street
# Cuisine: steak_house;sandwich
#
# NAME: Music Millennium
# Address: 3158 East Burnside Street
# Phone: +1-503-231-8926
#
# NAME: Rose Church
# Type: place_of_worship
# Address: 3212 Southeast Ankeny Street
#
# NAME: Stammtisch
# Type: pub
# Address: 401 Northeast 28th Avenue
# Cuisine: german
#
# NAME: Atlas Immersion Academy
# Type: kindergarten
# Address: 1211 Southeast 37th Avenue
#
# NAME: The Groves Church
# Type: place_of_worship
# Address: 3520 Southeast Yamhill Street
# Phone: +1-503-332-1858
#
# NAME: Northwest Battery Supply
# Address: 3750 Southeast Belmont Street
# Phone: +1-503-232-9002
#
# NAME: Smiles on Belmont
# Type: dentist
# Address: 3418 Southeast Belmont Street
# Phone: +1-503 236-3706
#
# NAME: Cooper's Co-op Cafe
# Type: restaurant
# Address: 2420 Southeast Belmont Street
# Phone: +15032334675
#
# NAME: Foreland Beer The Study
# Type: pub
# Address: 2511 Southeast Belmont Street
# Phone: +15034779526
#
# NAME: Serra Dispensary
# Address: 2519 Southeast Belmont Street
# Phone: +19715447055
#
# NAME: Rukdiew Cafe
# Type: restaurant
# Address: 2534 Southeast Belmont Street
# Cuisine: thai
# Phone: +15038416123
#
# NAME: The Nest Lounge & Patio
# Type: bar
# Address: 2715 Southeast Belmont Street
#
# NAME: Our House
# Type: social_facility
# Address: 2727 Southeast Alder Street
#
# NAME: Rivermark
# Type: bank
# Address: 3010 Southeast Belmont Street
#
# NAME: Mai Thai Restaurant
# Type: restaurant
# Address: 3104 Southeast Belmont Street
# Cuisine: thai
# Phone: +1-503-232-9844
#
# NAME: Door of Hope
# Type: place_of_worship
# Address: 3210 Southeast Taylor Street
#
# NAME: Metropolitan Family Service
# Type: social_facility
# Address: 1808 Southeast Belmont Street
#
# NAME: The Low Tide Lounge
# Type: bar
# Address: 2045 Southeast Belmont Street
# Phone: +1-503-477-8394
#
# NAME: Jade Rabbit
# Type: restaurant
# Address: 2304 Southeast Belmont Street
# Cuisine: asian;chinese
#
# NAME: Pad Thai Kitchen
# Type: restaurant
# Address: 2309 Southeast Belmont Street
# Cuisine: thai
# Phone: +15032328766
#
# NAME: Penny Market
# Address: 2001 Southeast Stark Street
#
# NAME: Screen Door
# Type: restaurant
# Address: 2337 East Burnside Street
# Cuisine: american
# Phone: +1-503-542-0880
#
# NAME: Grace and Truth Pentecostal Church
# Type: place_of_worship
# Address: 420 Southeast 22nd Avenue
#
# NAME: Nationale
# Address: 15 Southeast 22nd Avenue
#
# NAME: Oregon Park Basketball Court
#
# NAME: Hinson Baptist Church
# Type: place_of_worship
# Address: 1137 Southeast 20th Avenue
#
# NAME: Hollywood Beverage
# Address: 3028 Northeast Sandy Boulevard
#
# NAME: Lloyd Center
#
# NAME: U-Store Self Storage
# Address: 1130 Northeast 28th Avenue
#
# NAME: Townhouse Pet Care
# Type: animal_boarding
# Address: 2965 Northeast Sandy Boulevard
#
# NAME: VCA Laurelhurst Animal Hospital
# Type: veterinary
# Address: 2935-2945 Northeast Sandy Boulevard
#
# NAME: Steam PDX
# Type: public_bath
# Address: 2885 Northeast Sandy Boulevard
#
# NAME: Bricks & Minifigs
# Address: 3040 Northeast Sandy Boulevard
# Phone: +1-503-908-3639
#
# NAME: Citizens Photo
# Address: 3070 Northeast Sandy Boulevard
# Phone: +1-503-232-8501
#
# NAME: Katie O'Brien's
# Type: pub
# Address: 2809 Northeast Sandy Boulevard
# Cuisine: american
#
# NAME: Collective Awakenings
# Address: 2823 Northeast Sandy Boulevard
#
# NAME: Centaur Guitar
# Address: 2833 Northeast Sandy Boulevard
#
# NAME: ReRack
# Address: 2240 Northeast Sandy Boulevard
# Phone: +1-503-875-6055
#
# NAME: Laurelhurst Village
# Type: social_facility
#
# NAME: The Matador
# Type: restaurant
# Address: 2424 East Burnside Street
#
# NAME: 76
# Type: fuel
# Address: 2020 East Burnside Street
#
# NAME: Rocket
# Address: 2020 East Burnside Street
#
# NAME: Plaid Pantry
# Address: 2983 Southeast Belmont Street
#
# NAME: The Tao of Tea
# Type: cafe
# Address: 3430 Southeast Belmont Street
#
# NAME: Plaid Pantry
# Address: 3318 Northeast Sandy Boulevard
#
# NAME: I've Been Framed
# Address: 2819 Southeast Ash Street
# Phone: +1-503-234-7102
#
# NAME: Vitalidad Movement Arts Center
# Type: dancing_school
# Address: 2648 East Burnside Street
# Phone: +1-503-327-8168
#
# NAME: Burnside Collision
# Address: 2712 East Burnside Street
#
# NAME: Little Baja
# Address: 1510 East Burnside Street
#
# NAME: Le Monde French Immersion Public Charter School
# Type: school
# Address: 2044 East Burnside Street
#
# NAME: Colonel Summers Splash Pad
#
# NAME: Portland Loo
# Type: toilets
#
# NAME: Willoughby Hearing
# Address: 1939 East Burnside Street
#
# NAME: MorningStar at Laurelhurst
# Type: social_facility
# Address: 3140 Northeast Sandy Boulevard
#
# NAME: Eighth Church of Christ Scientist
# Type: place_of_worship
# Address: 3505 Northeast Multnomah Street
#
# NAME: The Mont
# Type: restaurant
# Address: 2411 Southeast Belmont Street
# Cuisine: diner;brunch
# Phone: +15038890102
#
# NAME: Alliance High School
# Type: school
# Address: 1530 Northeast Glisan Street
# Phone: +1-503-916-6486
#
# NAME: Le Monde French Immersion Public Charter School
# Type: school
# Address: 2044 East Burnside Street
#
# NAME: Oregon Park Playground
#
# NAME: Hawthorne Gardens
# Type: social_facility
# Address: 2828 Southeast Taylor Street
# Phone: +1 844 630 7334

# %%
# Get address coordinates
address_coords = ox.geocode(address)

# Create interactive map with light basemap
m = folium.Map(
    location=address_coords,
    zoom_start=18,
    tiles='OpenStreetMap'  # Light, readable basemap
)

# Blue marker for the address
folium.CircleMarker(
    address_coords,
    radius=10,
    popup='<b>{}</b>'.format(address),
    color='#2E86DE',
    fill=True,
    fillColor='#2E86DE',
    fillOpacity=1.0,
    weight=3
).add_to(m)

# Red markers for businesses
for idx, row in businesses_filtered.iterrows():
    if 'geometry' in row and row['geometry']:
        coords = [row['geometry'].centroid.y, row['geometry'].centroid.x]
        name = row.get('name', 'Unknown')
        entity_type = row.get('amenity') or row.get('shop') or row.get('tourism') or row.get('leisure')
        
        folium.CircleMarker(
            coords,
            radius=6,
            popup='<b>{}</b><br>{}'.format(name, entity_type),
            color='#EE5A6F',
            fill=True,
            fillColor='#EE5A6F',
            fillOpacity=0.8
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4197ba5c4d612489fe88a3ea9a161e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4197ba5c4d612489fe88a3ea9a161e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4197ba5c4d612489fe88a3ea9a161e7 = L.map(
#                 &quot;map_f4197ba5c4d612489fe88a3ea9a161e7&quot;,
#                 {
#                     center: [45.5227479, -122.6377033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8847b341f2b0672c31ef91b2dbf51188 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8847b341f2b0672c31ef91b2dbf51188.addTo(map_f4197ba5c4d612489fe88a3ea9a161e7);
#
#
#             var circle_marker_dd56f0cff4631b2e0e467c8d1b74aa22 = L.circleMarker(
#                 [45.5227479, -122.6377033],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2E86DE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2E86DE&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f4197ba5c4d612489fe88a3ea9a161e7);
#
#
#         var popup_29d172f95b975315ae11d0177bc87bc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5adf80ececc2012f84a5d5b1eb1ae261 = $(`&lt;div id=&quot;html_5adf80ececc2012f84a5d5b1eb1ae261&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;2724 E Burnside St, Portland, OR 97214&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_29d172f95b975315ae11d0177bc87bc8.setContent(html_5adf80ececc2012f84a5d5b1eb1ae261);
#
#
#
#         circle_marker_dd56f0cff4631b2e0e467c8d1b74aa22.bindPopup(popup_29d172f95b975315ae11d0177bc87bc8)
#         ;
#
#
#
#
#             var circle_marker_ca52c1e88079f8916429b8bc640d9395 = L.circleMarker(
#                 [45.5260208, -122.6430376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f4197ba5c4d612489fe88a3ea9a161e7);
#
#
#         var popup_e41e76741bc4c0b962a52fb1554066a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d811cf27685ae7bc303938e34c359ad6 = $(`&lt;div id=&quot;html_d811cf27685ae7bc303938e34c359ad6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kerr Youth Center at Wynne Watts School&lt;/b&gt;&lt;br&gt;school&lt;/div&gt;`)[0];
#                 popup_e41e76741bc4c0b962a52fb1554066a3.setContent(html_d811cf27685ae7bc303938e34c359ad6);
#
#
#
#         circle_marker_ca52c1e88079f8916429b8bc640d9395.bindPopup(popup_e41e76741bc4c0b962a52fb1554066a3)
#         ;
#
#
#
#
#             var circle_marker_7e7cedeb01e16fd55b8170f6f02fd960 = L.circleMarker(
#                 [45.5252727, -122.6456449],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f4197ba5c4d612489fe88a3ea9a161e7);
#
#
#         var popup_087be80904b61a9215dbbafcdef7e879 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95754bd391e7f21746e228998130553c = $(`&lt;div id=&quot;html_95754bd391e7f21746e228998130553c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Aquarian Foundation&lt;/b&gt;&lt;br&gt;place_of_worship&lt;/div&gt;`)[0];
#                 popup_087be80904b61a9215dbbafcdef7e879.setContent(html_95754bd391e7f21746e228998130553c);
#
#
#
#         circle_marker

# %% [markdown]
# # Portland Spots
#
# I want to see the Portland paper drop spots on one map. I drop GrooveSeeker papers off at these spots.

# %%
spots = {}

spots['Rose City Guitar Company'] = {}
spots['Rose City Guitar Company']['address'] = '2724 E Burnside St, Portland, OR 97214'

spots['Everyday Music'] = {}
spots['Everyday Music']['address'] = '1313 W Burnside St, Portland, OR 97209'

spots['Portland Outdoor Store'] = {}
spots['Portland Outdoor Store']['address'] = '304 SW 3rd Ave, Portland, OR 97204'

spots['Music Millennium'] = {}
spots['Music Millennium']['address'] = '3158 E Burnside St, Portland, OR 97214'

spots['Portland Saturday Market'] = {}
spots['Portland Saturday Market']['address'] = '98 SW Naito Parkway, Portland, OR 97204'

spots['2nd Avenue Records'] = {}
spots['2nd Avenue Records']['address'] = '121 SW 2nd Ave, Portland, OR 97204'

spots['Platinum Records Lights & Sound'] = {}
spots['Platinum Records Lights & Sound']['address'] = '104 SW 2nd Ave, Portland, OR 97204'

spots['Sinister Coffee and Creamery'] = {}
spots['Sinister Coffee and Creamery']['address'] = '301 SW Morrison St. Portland, OR 97204'


spots['503 Records'] = {}
spots['503 Records']['address'] = '3899 SW Hall Blvd, Beaverton, OR 97005'

spots['Brickhaus Coffee'] = {}
spots['Brickhaus Coffee']['address'] = '12600 SW Crescent St, Beaverton, OR 97005'

spots['Insomnia Coffee'] = {}
spots['Insomnia Coffee']['address'] = '317 E Main St, Hillsboro, OR 97123'

spots['Heritage Bank'] = {}
spots['Heritage Bank']['address'] = '314 E Main St, Hillsboro, OR 97123'


spots['The Artfull Garden'] = {}
spots['The Artfull Garden']['address'] = '222 E Main St, Hillsboro, OR 97123'

spots['ColoursArt'] = {}
spots['ColoursArt']['address'] = '270 E Main St, Hillsboro, OR 97123'

spots['Chicatanas'] = {}
spots['Chicatanas']['address'] = '159 SE 2nd Ave, Hillsboro, OR 97123'

spots["Dee's Divine Finds"] = {}
spots["Dee's Divine Finds"]['address'] = '176 NE 3rd Ave, Hillsboro, OR 97124'

spots['Fat Baby Barbecue'] = {}
spots['Fat Baby Barbecue']['address'] = '264 E Main St, Hillsboro, OR 97123'

spots['3 Goats Vineyard'] = {}
spots['3 Goats Vineyard']['address'] = '139 SE 2nd Ave, Hillsboro, OR 97123'

spots['Tall Trees Taphouse'] = {}
spots['Tall Trees Taphouse']['address'] = '233 E Main St, Hillsboro, OR 97123'

spots['The One Horse Taphouse'] = {}
spots['The One Horse Taphouse']['address'] = '1198 NE Orenco Station Pkwy, Hillsboro, OR 97124'

spots["Mo'o Manu Tattoo"] = {}
spots["Mo'o Manu Tattoo"]['address'] = '203 E Main St, Hillsboro, OR 97123'

spots['New Seasons Market'] = {}
spots['New Seasons Market']['address'] = '1453 NE 61st Ave, Hillsboro, OR 97124'

spots['Hillsboro Downtown Station'] = {}
spots['Hillsboro Downtown Station']['address'] = '320 SE Baseline St, Hillsboro, OR 97123'

spots['Collective Kitchen'] = {}
spots['Collective Kitchen']['address'] = '173 NE 3rd Ave, Hillsboro, OR 97124'

spots["Le'Stuff Antique Mall"] = {}
spots["Le'Stuff Antique Mall"]['address'] = '234 E Main St, Hillsboro, OR 97123'

spots['Crema Coffee + Bakery'] = {}
spots['Crema Coffee + Bakery']['address'] = '2728 SE Ankeny St, Portland, OR 97214'

spots['AR Workshop'] = {}
spots['AR Workshop']['address'] = '1114 NE Orenco Station Pkwy, Hillsboro, OR 97124'

spots['MIR Music'] = {}
spots['MIR Music']['address'] = '331 E Main St, Hillsboro, OR 97123'

spots['Bennett Urban Farm Store'] = {}
spots['Bennett Urban Farm Store']['address'] = '276 E Main St, Hillsboro, OR 97123'

spots['Willow & Ash'] = {}
spots['Willow & Ash']['address'] = '244 E Main St, Hillsboro, OR 97123'

spots['Democratic Party of Washington County'] = {}
spots['Democratic Party of Washington County']['address'] = '140 NE 3rd Ave, Hillsboro, OR 97124'

spots['Avery at Orenco Station'] = {}
spots['Avery at Orenco Station']['address'] = '6199 NE Alder St, Hillsboro, OR 97124'

spots['Bag & Baggage Productions'] = {}
spots['Bag & Baggage Productions']['address'] = '350 E Main St, Hillsboro, OR 97123'



spots['Hello Sunshine Art + Vintage'] = {}
spots['Hello Sunshine Art + Vintage']['address'] = '3022 E Burnside St, Portland, OR 97214'


spots['DAnu Wines'] = {}
spots['DAnu Wines']['address'] = '173 NE 3rd Ave Ste 107, Hillsboro, OR 97124'

spots['Résolu Cellars'] = {}
spots['Résolu Cellars']['address'] = '262 SE 4th Ave, Hillsboro, OR 97123'

spots['Portland Visitor Center'] = {}
spots['Portland Visitor Center']['address'] = '1132 SW Harvey Milk St, Portland, OR 97205'



# vintage store, tourism place, danu


# as venues, record stores, and music shops become paper drop spots, they can become red dots
# i will simply add them here and they will show as red dots instead of the other colors

spots
# Out:
# {'Rose City Guitar Company': {'address': '2724 E Burnside St, Portland, OR 97214'},
#  'Everyday Music': {'address': '1313 W Burnside St, Portland, OR 97209'},
#  'Portland Outdoor Store': {'address': '304 SW 3rd Ave, Portland, OR 97204'},
#  'Music Millennium': {'address': '3158 E Burnside St, Portland, OR 97214'},
#  'Portland Saturday Market': {'address': '98 SW Naito Parkway, Portland, OR 97204'},
#  '2nd Avenue Records': {'address': '121 SW 2nd Ave, Portland, OR 97204'},
#  'Platinum Records Lights & Sound': {'address': '104 SW 2nd Ave, Portland, OR 97204'},
#  'Sinister Coffee and Creamery': {'address': '301 SW Morrison St. Portland, OR 97204'},
#  '503 Records': {'address': '3899 SW Hall Blvd, Beaverton, OR 97005'},
#  'Brickhaus Coffee': {'address': '12600 SW Crescent St, Beaverton, OR 97005'},
#  'Insomnia Coffee': {'address': '317 E Main St, Hillsboro, OR 97123'},
#  'Heritage Bank': {'address': '314 E Main St, Hillsboro, OR 97123'},
#  'The Artfull Garden': {'address': '222 E Main St, Hillsboro, OR 97123'},
#  'ColoursArt': {'address': '270 E Main St, Hillsboro, OR 97123'},
#  'Chicatanas': {'address': '159 SE 2nd Ave, Hillsboro, OR 97123'},
#  "Dee's Divine Finds": {'address': '176 NE 3rd Ave, Hillsboro, OR 97124'},
#  'Fat Baby Barbecue': {'address': '264 E Main St, Hillsboro, OR 97123'},
#  '3 Goats Vineyard': {'address': '139 SE 2nd Ave, Hillsboro, OR 97123'},
#  'Tall Trees Taphouse': {'address': '233 E Main St, Hillsboro, OR 97123'},
#  'The One Horse Taphouse': {'address': '1198 NE Orenco Station Pkwy, Hillsboro, OR 97124'},
#  "Mo'o Manu Tattoo": {'address': '203 E Main St, Hillsboro, OR 97123'},
#  'New Seasons Market': {'address': '1453 NE 61st Ave, Hillsboro, OR 97124'},
#  'Hillsboro Downtown Station': {'address': '320 SE Baseline St, Hillsboro, OR 97123'},
#  'Collective Kitchen': {'address': '173 NE 3rd Ave, Hillsboro, OR 97124'},
#  "Le'Stuff Antique Mall": {'address': '234 E Main St, Hillsboro, OR 97123'},
#  'Crema Coffee + Bakery': {'address': '2728 SE Ankeny St, Portland, OR 97214'},
#  'AR Workshop': {'address': '1114 NE Orenco Station Pkwy, Hillsboro, OR 97124'},
#  'MIR Music': {'address': '331 E Main St, Hillsboro, OR 97123'},
#  'Bennett Urban Farm Store': {'address': '276 E Main St, Hillsboro, OR 97123'},
#  'Willow & Ash': {'address': '244 E Main St, Hillsboro, OR 97123'},
#  'Democratic Party of Washington County': {'address': '140 NE 3rd Ave, Hillsboro, OR 97124'},
#  'Avery at Orenco Station': {'address': '6199 NE Alder St, Hillsboro, OR 97124'},
#  'Bag & Baggage Productions': {'address': '350 E Main St, Hillsboro, OR 97123'},
#  'Hello Sunshine Art + Vintage': {'address': '3022 E Burnside St, Portland, OR 97214'},
#  'DAnu Wines': {'address': '173 NE 3rd Ave Ste 107, Hillsboro, OR 97124'},
#  'Résolu Cellars': {'address': '262 SE 4th Ave, Hillsboro, OR 97123'},
#  'Portland Visitor Center': {'address': '1132 SW Harvey Milk St, Portland, OR 97205'}}

# %%
for name, data in sorted(spots.items()):
    print(f"{name}\n{data['address']}\n")
# Out:
# 2nd Avenue Records
# 121 SW 2nd Ave, Portland, OR 97204
#
# 3 Goats Vineyard
# 139 SE 2nd Ave, Hillsboro, OR 97123
#
# 503 Records
# 3899 SW Hall Blvd, Beaverton, OR 97005
#
# AR Workshop
# 1114 NE Orenco Station Pkwy, Hillsboro, OR 97124
#
# Avery at Orenco Station
# 6199 NE Alder St, Hillsboro, OR 97124
#
# Bag & Baggage Productions
# 350 E Main St, Hillsboro, OR 97123
#
# Bennett Urban Farm Store
# 276 E Main St, Hillsboro, OR 97123
#
# Brickhaus Coffee
# 12600 SW Crescent St, Beaverton, OR 97005
#
# Chicatanas
# 159 SE 2nd Ave, Hillsboro, OR 97123
#
# Collective Kitchen
# 173 NE 3rd Ave, Hillsboro, OR 97124
#
# ColoursArt
# 270 E Main St, Hillsboro, OR 97123
#
# Crema Coffee + Bakery
# 2728 SE Ankeny St, Portland, OR 97214
#
# DAnu Wines
# 173 NE 3rd Ave Ste 107, Hillsboro, OR 97124
#
# Dee's Divine Finds
# 176 NE 3rd Ave, Hillsboro, OR 97124
#
# Democratic Party of Washington County
# 140 NE 3rd Ave, Hillsboro, OR 97124
#
# Everyday Music
# 1313 W Burnside St, Portland, OR 97209
#
# Fat Baby Barbecue
# 264 E Main St, Hillsboro, OR 97123
#
# Hello Sunshine Art + Vintage
# 3022 E Burnside St, Portland, OR 97214
#
# Heritage Bank
# 314 E Main St, Hillsboro, OR 97123
#
# Hillsboro Downtown Station
# 320 SE Baseline St, Hillsboro, OR 97123
#
# Insomnia Coffee
# 317 E Main St, Hillsboro, OR 97123
#
# Le'Stuff Antique Mall
# 234 E Main St, Hillsboro, OR 97123
#
# MIR Music
# 331 E Main St, Hillsboro, OR 97123
#
# Mo'o Manu Tattoo
# 203 E Main St, Hillsboro, OR 97123
#
# Music Millennium
# 3158 E Burnside St, Portland, OR 97214
#
# New Seasons Market
# 1453 NE 61st Ave, Hillsboro, OR 97124
#
# Platinum Records Lights & Sound
# 104 SW 2nd Ave, Portland, OR 97204
#
# Portland Outdoor Store
# 304 SW 3rd Ave, Portland, OR 97204
#
# Portland Saturday Market
# 98 SW Naito Parkway, Portland, OR 97204
#
# Portland Visitor Center
# 1132 SW Harvey Milk St, Portland, OR 97205
#
# Rose City Guitar Company
# 2724 E Burnside St, Portland, OR 97214
#
# Résolu Cellars
# 262 SE 4th Ave, Hillsboro, OR 97123
#
# Sinister Coffee and Creamery
# 301 SW Morrison St. Portland, OR 97204
#
# Tall Trees Taphouse
# 233 E Main St, Hillsboro, OR 97123
#
# The Artfull Garden
# 222 E Main St, Hillsboro, OR 97123
#
# The One Horse Taphouse
# 1198 NE Orenco Station Pkwy, Hillsboro, OR 97124
#
# Willow & Ash
# 244 E Main St, Hillsboro, OR 97123

# %%
locations = ", ".join(name for name, data in sorted(spots.items()))
print(locations)
# Out:
# 2nd Avenue Records, 3 Goats Vineyard, 503 Records, AR Workshop, Avery at Orenco Station, Bag & Baggage Productions, Bennett Urban Farm Store, Brickhaus Coffee, Chicatanas, Collective Kitchen, ColoursArt, Crema Coffee + Bakery, DAnu Wines, Dee's Divine Finds, Democratic Party of Washington County, Everyday Music, Fat Baby Barbecue, Hello Sunshine Art + Vintage, Heritage Bank, Hillsboro Downtown Station, Insomnia Coffee, Le'Stuff Antique Mall, MIR Music, Mo'o Manu Tattoo, Music Millennium, New Seasons Market, Platinum Records Lights & Sound, Portland Outdoor Store, Portland Saturday Market, Portland Visitor Center, Rose City Guitar Company, Résolu Cellars, Sinister Coffee and Creamery, Tall Trees Taphouse, The Artfull Garden, The One Horse Taphouse, Willow & Ash

# %%
import osmnx as ox
import folium

# Geocode all spots
for name, data in spots.items():
    coords = ox.geocode(data['address'])
    spots[name]['coords'] = coords

# Build map centered on Portland
m = folium.Map(location=[45.5231, -122.6765], zoom_start=13, tiles='OpenStreetMap')

# Plot each spot
for name, data in spots.items():
    # 1 mile ring
    folium.Circle(
        location=data['coords'],
        radius=1609,
        color='#EE5A6F',
        fill=False,
        weight=1
    ).add_to(m)

    # Center dot
    folium.CircleMarker(
        data['coords'],
        radius=8,
        popup='<b>{}</b><br>{}'.format(name, data['address']),
        color='#EE5A6F',
        fill=True,
        fillColor='#EE5A6F',
        fillOpacity=0.8
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86823cb0d643f894d1a6505be1d2a221 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86823cb0d643f894d1a6505be1d2a221&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86823cb0d643f894d1a6505be1d2a221 = L.map(
#                 &quot;map_86823cb0d643f894d1a6505be1d2a221&quot;,
#                 {
#                     center: [45.5231, -122.6765],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4105a69c5dcb46bc17500143108fdc9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4105a69c5dcb46bc17500143108fdc9.addTo(map_86823cb0d643f894d1a6505be1d2a221);
#
#
#             var circle_9f406c5c6d48c85b28f43e495595f470 = L.circle(
#                 [45.5227479, -122.6377033],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1609, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_86823cb0d643f894d1a6505be1d2a221);
#
#
#             var circle_marker_da56671ef77d425b2ab19211d1b9ccaf = L.circleMarker(
#                 [45.5227479, -122.6377033],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86823cb0d643f894d1a6505be1d2a221);
#
#
#         var popup_10658d9a4ad9d018748d38a5530b852a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_498cdb8ea7c66ccb858a1cb63f0e49be = $(`&lt;div id=&quot;html_498cdb8ea7c66ccb858a1cb63f0e49be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rose City Guitar Company&lt;/b&gt;&lt;br&gt;2724 E Burnside St, Portland, OR 97214&lt;/div&gt;`)[0];
#                 popup_10658d9a4ad9d018748d38a5530b852a.setContent(html_498cdb8ea7c66ccb858a1cb63f0e49be);
#
#
#
#         circle_marker_da56671ef77d425b2ab19211d1b9ccaf.bindPopup(popup_10658d9a4ad9d018748d38a5530b852a)
#         ;
#
#
#
#
#             var circle_45436969b931456b31d50d492de39ff7 = L.circle(
#                 [45.5230618, -122.6849466],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1609, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_86823cb0d643f894d1a6505be1d2a221);
#
#
#             var circle_marker_99a36b0b7ef536f10ec57f87a9d5548a = L.circleMarker(
#                 [45.5230618, -122.6849466],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86823cb0d643f894d1a6505be1d2a221);
#
#
#         var popup_4cdfea2b04b10b28aa97009df77d3306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3010b12b4575a1422a57c4929d868525 = $(`&lt;div id=&quot;html_3010b12b4575a1422a57c4929d868525&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Everyday Music&lt;/b&gt;&lt;br&gt;1313 W Burnside St, Portland, OR 97209&lt;/div&gt;`)[0];
#                 popup_4cdfea2b04b10b28aa97009df77d3306.setContent(html_3010b12b4575a1422a57c4929d868525);

# %%
import osmnx as ox
import folium

# Geocode all spots
for name, data in spots.items():
    coords = ox.geocode(data['address'])
    spots[name]['coords'] = coords

# Build map centered on Portland
m = folium.Map(location=[45.5231, -122.6765], zoom_start=13, tiles='OpenStreetMap')

# Plot each spot
for name, data in spots.items():
    # 1km glow ring
    folium.Circle(
        location=data['coords'],
        radius=1609,
        color='#EE5A6F',
        fill=True,
        fillColor='#EE5A6F',
        fillOpacity=0.15,
        weight=1
    ).add_to(m)

    # Center dot
    folium.CircleMarker(
        data['coords'],
        radius=8,
        popup='<b>{}</b><br>{}'.format(name, data['address']),
        color='#EE5A6F',
        fill=True,
        fillColor='#EE5A6F',
        fillOpacity=0.8
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7531ecc77393e77e3840952ebf2a6af9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7531ecc77393e77e3840952ebf2a6af9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7531ecc77393e77e3840952ebf2a6af9 = L.map(
#                 &quot;map_7531ecc77393e77e3840952ebf2a6af9&quot;,
#                 {
#                     center: [45.5231, -122.6765],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6813fbf48fea6b2867f32f2d962e3721 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6813fbf48fea6b2867f32f2d962e3721.addTo(map_7531ecc77393e77e3840952ebf2a6af9);
#
#
#             var circle_71a21a221d282f27d7efbd3ec9c8f9ff = L.circle(
#                 [45.5227479, -122.6377033],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1609, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7531ecc77393e77e3840952ebf2a6af9);
#
#
#             var circle_marker_27269bb36867b18563e7fa1344e55694 = L.circleMarker(
#                 [45.5227479, -122.6377033],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7531ecc77393e77e3840952ebf2a6af9);
#
#
#         var popup_8b9ba377f1a83df355f793cbdb280bed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eae000ac4547f22bae9b9b9bcb58a1e1 = $(`&lt;div id=&quot;html_eae000ac4547f22bae9b9b9bcb58a1e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rose City Guitar Company&lt;/b&gt;&lt;br&gt;2724 E Burnside St, Portland, OR 97214&lt;/div&gt;`)[0];
#                 popup_8b9ba377f1a83df355f793cbdb280bed.setContent(html_eae000ac4547f22bae9b9b9bcb58a1e1);
#
#
#
#         circle_marker_27269bb36867b18563e7fa1344e55694.bindPopup(popup_8b9ba377f1a83df355f793cbdb280bed)
#         ;
#
#
#
#
#             var circle_9e447e347b527715d35c28fbe7c10fb1 = L.circle(
#                 [45.5230618, -122.6849466],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1609, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7531ecc77393e77e3840952ebf2a6af9);
#
#
#             var circle_marker_7cb7c05155b84e912b4f3a231954af1c = L.circleMarker(
#                 [45.5230618, -122.6849466],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE5A6F&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE5A6F&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7531ecc77393e77e3840952ebf2a6af9);
#
#
#         var popup_537959462d74591bdefd96a0b360e2eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_303d64f87f4fabdf16864de1eae67c91 = $(`&lt;div id=&quot;html_303d64f87f4fabdf16864de1eae67c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Everyday Music&lt;/b&gt;&lt;br&gt;1313 W Burnside St, Portland, OR 97209&lt;/div&gt;`)[0];
#                 popup_537959462d74591bdefd96a0b360e2eb.setContent(html_303d64f87f4fabdf16864de1eae67c91);

# %%
# add friendlies as red (friendly spots)
# add other known record, music, wine, and taphouses as blue (leadgen)

# %% [markdown]
# # Overlay Other Points of Interest
#
# Now, I want to overlay all other known record stores as blue dots so that I can easily find more places to drop off GrooveSeeker event papers.

# %%
# Record Stores

import pandas as pd

data = 'data/verdant_eye/gsv3/record_stores_pdx.csv'

record_store_df = pd.read_csv(data)

record_store_df['full_address'] = record_store_df['Address'] + ', ' + record_store_df['City'] + ', ' + record_store_df['State']
record_store_df = record_store_df[['Company Name', 'full_address']]
record_store_df.columns = ['company', 'address']
record_store_df.head()
# Out:
#               company                           address
# 0         503 Records  3899 SW Hall Blvd, Beaverton, OR
# 1  2nd Avenue Records      121 SW 2nd Ave, Portland, OR
# 2      Everyday Music  1313 W Burnside St, Portland, OR
# 3    Platinum Records      104 SW 2nd Ave, Portland, OR
# 4      Exiled Records   8685 SW Canyon Rd, Portland, OR

# %%
# Music Stores

data = 'data/verdant_eye/gsv3/music_stores_pdx.csv'

music_store_df = pd.read_csv(data)

music_store_df['full_address'] = music_store_df['Address'] + ', ' + music_store_df['City'] + ', ' + music_store_df['State']
music_store_df = music_store_df[['Company Name', 'full_address']]
music_store_df.columns = ['company', 'address']
music_store_df.head()
# Out:
#                     company                                      address
# 0                 MIR Music                 331 E Main St, Hillsboro, OR
# 1  Beaverton Music Services           12480 SW 1st Street, Beaverton, OR
# 2         Five Star Guitars  17305 NW Corridor Ct Ste 100, Beaverton, OR
# 3             Guitar Center           9575 SW Cascade Ave, Beaverton, OR
# 4    Portland Music Company       10075 SW Beav-Hills Hwy, Beaverton, OR

# %%
# Venues

data = 'data/verdant_eye/gsv3/venues_pdx.csv'

venue_df = pd.read_csv(data)

venue_df['full_address'] = venue_df['Address'] + ', ' + venue_df['City'] + ', ' + venue_df['State']
venue_df = venue_df[['Company Name', 'full_address']]
venue_df.columns = ['company', 'address']
venue_df.head()
# Out:
#                        company                               address
# 0              Revolution Hall        1300 SE Stark St, Portland, OR
# 1          Mississippi Studios  3939 N Mississippi Ave, Portland, OR
# 2             Crystal Ballroom      1332 W Burnside St, Portland, OR
# 3  The Old Church Concert Hall        1422 SW 11th Ave, Portland, OR
# 4              Aladdin Theater   3017 SE Milwaukie Ave, Portland, OR

# %%
# Geocode all spots
for name, data in spots.items():
    coords = ox.geocode(data['address'])
    spots[name]['coords'] = coords

# Geocode check_df rows
def safe_geocode(address):
    try:
        return ox.geocode(address)
    except Exception:
        return None

record_store_df['coords'] = record_store_df['address'].apply(safe_geocode)
record_store_df = record_store_df[record_store_df['coords'].notna()]

music_store_df['coords'] = music_store_df['address'].apply(safe_geocode)
music_store_df = music_store_df[music_store_df['coords'].notna()]

venue_df['coords'] = venue_df['address'].apply(safe_geocode)
venue_df = venue_df[venue_df['coords'].notna()]

# Build map centered on Portland
m = folium.Map(location=[45.5231, -122.6765], zoom_start=13, tiles='OpenStreetMap')

# blue dots: record stores
for _, row in record_store_df.iterrows():
    folium.CircleMarker(
        row['coords'],
        radius=8,
        popup='<b>{}</b><br>{}'.format(row['company'], row['address']),
        color='#2E86DE',
        fill=True,
        fillColor='#2E86DE',
        fillOpacity=0.8
    ).add_to(m)

# green dots: music stores
for _, row in music_store_df.iterrows():
    folium.CircleMarker(
        row['coords'],
        radius=8,
        popup='<b>{}</b><br>{}'.format(row['company'], row['address']),
        color='#2ECC71',
        fill=True,
        fillColor='#2ECC71',
        fillOpacity=0.8
    ).add_to(m)

# purple dots: venues
for _, row in venue_df.iterrows():
    folium.CircleMarker(
        row['coords'],
        radius=8,
        popup='<b>{}</b><br>{}'.format(row['company'], row['address']),
        color='#9B59B6',
        fill=True,
        fillColor='#9B59B6',
        fillOpacity=0.8
    ).add_to(m)

# red dots: paper drop spots
for name, data in spots.items():
    folium.CircleMarker(
        data['coords'],
        radius=8,
        popup='<b>{}</b><br>{}'.format(name, data['address']),
        color='#EE5A6F',
        fill=True,
        fillColor='#EE5A6F',
        fillOpacity=0.8
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8aadf2abfc2329e50cd2dab3b08489bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8aadf2abfc2329e50cd2dab3b08489bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8aadf2abfc2329e50cd2dab3b08489bc = L.map(
#                 &quot;map_8aadf2abfc2329e50cd2dab3b08489bc&quot;,
#                 {
#                     center: [45.5231, -122.6765],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f0f3f3a6956e40b6d8e0b912045df30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f0f3f3a6956e40b6d8e0b912045df30.addTo(map_8aadf2abfc2329e50cd2dab3b08489bc);
#
#
#             var circle_marker_1031ffc41f5a8e545a1936a36b1a29dc = L.circleMarker(
#                 [45.491336, -122.80585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2E86DE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2E86DE&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8aadf2abfc2329e50cd2dab3b08489bc);
#
#
#         var popup_c08bd8a89c9c40de1ce5a838fd324c7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8adb907e769f4e7a493a70496fbfea2f = $(`&lt;div id=&quot;html_8adb907e769f4e7a493a70496fbfea2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;503 Records&lt;/b&gt;&lt;br&gt;3899 SW Hall Blvd, Beaverton, OR&lt;/div&gt;`)[0];
#                 popup_c08bd8a89c9c40de1ce5a838fd324c7f.setContent(html_8adb907e769f4e7a493a70496fbfea2f);
#
#
#
#         circle_marker_1031ffc41f5a8e545a1936a36b1a29dc.bindPopup(popup_c08bd8a89c9c40de1ce5a838fd324c7f)
#         ;
#
#
#
#
#             var circle_marker_0fd0529e22a67aaeb35fca688c76e573 = L.circleMarker(
#                 [45.5218228, -122.6726074],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2E86DE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2E86DE&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8aadf2abfc2329e50cd2dab3b08489bc);
#
#
#         var popup_60126dd1206edf44d5bf79621bd9cbb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9ddd46cf4af83a58235b1fb604c3925 = $(`&lt;div id=&quot;html_d9ddd46cf4af83a58235b1fb604c3925&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;2nd Avenue Records&lt;/b&gt;&lt;br&gt;121 SW 2nd Ave, Portland, OR&lt;/div&gt;`)[0];
#                 popup_60126dd1206edf44d5bf79621bd9cbb8.setContent(html_d9ddd46cf4af83a58235b1fb604c3925);
#
#
#
#         circle_marker_0fd0529e22a67aaeb35fca688c76e573.bindPopup(popup_60126dd1206edf44d5bf79621bd9cbb8)
#         ;
#
#
#
#
#             var circle_marker_49c7438bf633d1bc9e7c44262384b848 = L.circleMarker(
#                 [45.5230618, -122.6849466],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2E86DE&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2E86DE&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8aadf2abfc2329e50cd2dab3b08489bc);
#
#
#         var popup_82121659afbf83260faf7905538409b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1dfbc6a0190aac3bf8b2bc67ea56bdd = $(`&lt;div id=&quot;html_a1dfbc6a0190aac3bf8b2bc67ea56bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Everyday Music&lt;/b&gt;&lt;br&gt;1313 W Burnside St, Portland, OR&lt;/div&gt;`)[0];
#                 popup_82121659afbf83260faf7905538409b5.setContent(html_a1dfbc6a0190aac3bf8b2bc67ea56bdd);

# %%
# Perfect. That's all I needed today. I just want to be able to see what is near my event paper drop spots.
