# %%
from gradio_client import Client   # for api use

import ast                         # for text to list conversion (make data useful)
import pandas as pd                # for easy data use; you can use polars or whatever you like

# start 8:14pm

# %% [markdown]
# # Accessing the API
#
# Accessing the API is simple. You pass your key to the client, and then you will see a message the API has loaded.

# %%
token = '../api_creds/vi_key_1.csv'

# load my key
df = pd.read_csv(token) # easy and lazy lol; using pandas anyway ;p
api_key = df['key'][0]  # easy and lazy lol; using pandas anyway ;p

# connect to api
client = Client("verdantdavid/grooveseeker-feeds", token=api_key)
# Out:
# Loaded as API: https://verdantdavid-grooveseeker-feeds.hf.space

# %%
# search parameters
location = "Michigan"
start_date = "2026-09-01"
end_date = "2026-09-30"

# %%
feeds = client.predict(api_name="/discover_feeds")

feeds
# Out:
# ['discover_feeds',
#  'search_events',
#  'search_event_prices',
#  'search_locations',
#  'search_entities',
#  'search_entity_events',
#  'search_entity_event_prices',
#  'search_entity_collaborations',
#  'search_websites',
#  'search_website_entities',
#  'search_website_events',
#  'search_country_counts']

# %%
#location = 'San Francisco'

api_name = "/search_events"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(100)
# Out:
#                              event_date  \
# 0   2026-09-30T08:45:00.000000000+00:00
# 1   2026-09-30T00:00:00.000000000+00:00
# 2   2026-09-28T08:45:00.000000000+00:00
# 3   2026-09-27T14:00:00.000000000+00:00
# 4   2026-09-26T18:00:00.000000000+00:00
# ..                                  ...
# 91  2026-09-01T19:00:00.000000000+00:00
# 92  2026-09-01T19:00:00.000000000+00:00
# 93  2026-09-01T11:00:00.000000000+00:00
# 94  2026-09-01T10:00:00.000000000+00:00
# 95  2026-09-01T00:00:00.000000000+00:00
#
#                                           event_title  \
# 0                                  55+ Drop-In Hockey
# 1           Taking the Long Way 20th Anniversary Tour
# 2                                  55+ Drop-In Hockey
# 3   Oktoberfest: A Queer Afternoon at Dakota Inn R...
# 4                            Endless Summer Gala 2026
# ..                                                ...
# 91  Huron Valley Harmonizers Chapter of the Barber...
# ...

# %%
api_name = "/search_event_prices"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#                             event_date  \
# 0  2026-09-30T08:45:00.000000000+00:00
# 1  2026-09-28T08:45:00.000000000+00:00
# 2  2026-09-27T14:00:00.000000000+00:00
# 3  2026-09-26T18:00:00.000000000+00:00
# 4  2026-09-25T20:00:00.000000000+00:00
# 5  2026-09-25T19:00:00.000000000+00:00
# 6  2026-09-24T19:00:00.000000000+00:00
# 7  2026-09-24T11:30:00.000000000+00:00
# 8  2026-09-23T11:30:00.000000000+00:00
# 9  2026-09-22T11:30:00.000000000+00:00
#
#                                          event_title  \
# 0                                 55+ Drop-In Hockey
# 1                                 55+ Drop-In Hockey
# 2  Oktoberfest: A Queer Afternoon at Dakota Inn R...
# 3                           Endless Summer Gala 2026
# 4                        Jo Koy Stand-Up Performance
# 5           Jalasat: A Pop-Up Performance Series #11
# 6  Tales from the Archives: President Ford & Holland
# 7                                      810 Freestyle
# ...

# %%
api_name = "/search_locations"

results = client.predict(api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#              location
# 0            A Coruña
# 1              Aachen
# 2             Aalborg
# 3               Aalen
# 4  Aalener Innenstadt
# 5               Aarau
# 6             Aarburg
# 7              Aargau
# 8              Aarhus
# 9    Abbey Brauweiler

# %%
api_name = "/search_entities"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#                             event_date                             entity
# 0  2026-09-30T08:45:00.000000000+00:00                 810 Sports Complex
# 1  2026-09-30T00:00:00.000000000+00:00                        Fox Theatre
# 2  2026-09-30T00:00:00.000000000+00:00                         The Chicks
# 3  2026-09-28T08:45:00.000000000+00:00                 810 Sports Complex
# 4  2026-09-27T14:00:00.000000000+00:00             Dakota Inn Rathskeller
# 5  2026-09-27T14:00:00.000000000+00:00                          Samuel KO
# 6  2026-09-26T18:00:00.000000000+00:00             West Michigan Symphony
# 7  2026-09-26T18:00:00.000000000+00:00                     The Beach Boys
# 8  2026-09-26T18:00:00.000000000+00:00                        Maris Myers
# 9  2026-09-26T18:00:00.000000000+00:00  VanDyk Mortgage Convention Center

# %%
api_name = "/search_entity_events"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#                             event_date                             entity  \
# 0  2026-09-30T08:45:00.000000000+00:00                 810 Sports Complex
# 1  2026-09-30T00:00:00.000000000+00:00                        Fox Theatre
# 2  2026-09-30T00:00:00.000000000+00:00                         The Chicks
# 3  2026-09-28T08:45:00.000000000+00:00                 810 Sports Complex
# 4  2026-09-27T14:00:00.000000000+00:00             Dakota Inn Rathskeller
# 5  2026-09-27T14:00:00.000000000+00:00                          Samuel KO
# 6  2026-09-26T18:00:00.000000000+00:00             West Michigan Symphony
# 7  2026-09-26T18:00:00.000000000+00:00                     The Beach Boys
# 8  2026-09-26T18:00:00.000000000+00:00                        Maris Myers
# 9  2026-09-26T18:00:00.000000000+00:00  VanDyk Mortgage Convention Center
#
#                                          event_title
# 0                                 55+ Drop-In Hockey
# ...

# %%
api_name = "/search_entity_event_prices"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#                             event_date                             entity  \
# 0  2026-09-30T08:45:00.000000000+00:00                 810 Sports Complex
# 1  2026-09-28T08:45:00.000000000+00:00                 810 Sports Complex
# 2  2026-09-27T14:00:00.000000000+00:00             Dakota Inn Rathskeller
# 3  2026-09-27T14:00:00.000000000+00:00                          Samuel KO
# 4  2026-09-26T18:00:00.000000000+00:00             West Michigan Symphony
# 5  2026-09-26T18:00:00.000000000+00:00                     The Beach Boys
# 6  2026-09-26T18:00:00.000000000+00:00                        Maris Myers
# 7  2026-09-26T18:00:00.000000000+00:00  VanDyk Mortgage Convention Center
# 8  2026-09-26T18:00:00.000000000+00:00                      Funkle Jessie
# 9  2026-09-25T20:00:00.000000000+00:00                             Jo Koy
#
#                                          event_title  \
# 0                                 55+ Drop-In Hockey
# ...

# %%
api_name = "/search_entity_collaborations"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#    event_date                          entity  \
# 0  2026-09-30              810 Sports Complex
# 1  2026-09-30      Franke Center for the Arts
# 2  2026-09-30                  Jocelyn France
# 3  2026-09-30                     Rob Monahan
# 4  2026-09-30                     Fox Theatre
# 5  2026-09-30                      The Chicks
# 6  2026-09-28              810 Sports Complex
# 7  2026-09-28    Main Street Area Association
# 8  2026-09-28  A2 Summer Streets Music Series
# 9  2026-09-28                 Local musicians
#
#                                          event_title
# 0                                 55+ Drop-In Hockey
# 1                 Franke Center Fall Student Classes
# 2                 Franke Center Fall Student Classes
# 3                 Franke Center Fall Student Classes
# 4          Taking the Long Way 20th Anniversary Tour
# 5          Taking the Long Way 20th Anniversary Tour
# 6                                 55+ Drop-In Hockey
# ...

# %%
api_name = "/search_websites"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#                             event_date                   website  event_count
# 0  2026-09-30T08:45:00.000000000+00:00      810sportscomplex.com            1
# 1  2026-09-30T00:00:00.000000000+00:00          bostonherald.com            1
# 2  2026-09-28T08:45:00.000000000+00:00      810sportscomplex.com            1
# 3  2026-09-27T14:00:00.000000000+00:00          sickening.events            1
# 4  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org            1
# 5  2026-09-25T20:00:00.000000000+00:00   battlecreekenquirer.com            1
# 6  2026-09-25T19:00:00.000000000+00:00    arabamericanmuseum.org            1
# 7  2026-09-25T00:00:00.000000000+00:00        michiganpublic.org            1
# 8  2026-09-24T20:00:00.000000000+00:00           ticketsignup.io            2
# 9  2026-09-24T19:30:00.000000000+00:00           detroitnews.com            1

# %%
api_name = "/search_website_entities"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#                             event_date                   website  \
# 0  2026-09-30T08:45:00.000000000+00:00      810sportscomplex.com
# 1  2026-09-30T00:00:00.000000000+00:00          bostonherald.com
# 2  2026-09-30T00:00:00.000000000+00:00          bostonherald.com
# 3  2026-09-28T08:45:00.000000000+00:00      810sportscomplex.com
# 4  2026-09-27T14:00:00.000000000+00:00          sickening.events
# 5  2026-09-27T14:00:00.000000000+00:00          sickening.events
# 6  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 7  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 8  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 9  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
#
#                               entity
# 0                 810 Sports Complex
# 1                        Fox Theatre
# 2                         The Chicks
# 3                 810 Sports Complex
# 4             Dakota Inn Rathskeller
# ...

# %%
api_name = "/search_website_events"

results = client.predict(location=location, start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#                             event_date                   website  \
# 0  2026-09-30T08:45:00.000000000+00:00      810sportscomplex.com
# 1  2026-09-30T00:00:00.000000000+00:00          bostonherald.com
# 2  2026-09-28T08:45:00.000000000+00:00      810sportscomplex.com
# 3  2026-09-27T14:00:00.000000000+00:00          sickening.events
# 4  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 5  2026-09-25T20:00:00.000000000+00:00   battlecreekenquirer.com
# 6  2026-09-25T19:00:00.000000000+00:00    arabamericanmuseum.org
# 7  2026-09-25T00:00:00.000000000+00:00        michiganpublic.org
# 8  2026-09-24T20:00:00.000000000+00:00           ticketsignup.io
# 9  2026-09-24T20:00:00.000000000+00:00           ticketsignup.io
#
#                                          event_title
# 0                                 55+ Drop-In Hockey
# 1          Taking the Long Way 20th Anniversary Tour
# 2                                 55+ Drop-In Hockey
# ...

# %%
api_name = "/search_country_counts"

results = client.predict(start_date=start_date, end_date=end_date, api_name=api_name)

df = pd.DataFrame(results)

df.head(10)
# Out:
#           country  event_count
# 0   United States         3656
# 1  United Kingdom          526
# 2         Germany          445
# 3          Canada          208
# 4           Italy           99
# 5          France           88
# 6         Ireland           75
# 7         Romania           49
# 8         Georgia           47
# 9           Spain           44

# %% [markdown]
# # MCP Examples

# %%
from mcp import ClientSession
from mcp.client.streamable_http import streamablehttp_client

import json

MCP_ENDPOINT = "https://verdantdavid-grooveseeker-feeds.hf.space/gradio_api/mcp/"
HEADERS = {"Authorization": "Bearer {}".format(api_key)}

# %%
async def call_feed(tool_name, **arguments):

    tool_name = "grooveseeker_feeds_{}".format(tool_name)

    async with streamablehttp_client(MCP_ENDPOINT, headers=HEADERS) as (read, write, _):
        async with ClientSession(read, write) as session:
            await session.initialize()

            result = await session.call_tool(
                tool_name,
                arguments=arguments
            )

            return "\n".join(
                block.text
                for block in result.content
                if block.type == "text"
            )

# %%
async def list_tools():

    async with streamablehttp_client(MCP_ENDPOINT, headers=HEADERS) as (read, write, _):
        async with ClientSession(read, write) as session:
            await session.initialize()

            result = await session.list_tools()

            return [tool.name for tool in result.tools]

# %%
tools = await list_tools()
tools = sorted(tools)
tools
# Out:
# ['grooveseeker_feeds_discover_feeds',
#  'grooveseeker_feeds_search_country_counts',
#  'grooveseeker_feeds_search_entities',
#  'grooveseeker_feeds_search_entity_collaborations',
#  'grooveseeker_feeds_search_entity_event_prices',
#  'grooveseeker_feeds_search_entity_events',
#  'grooveseeker_feeds_search_event_prices',
#  'grooveseeker_feeds_search_events',
#  'grooveseeker_feeds_search_locations',
#  'grooveseeker_feeds_search_website_entities',
#  'grooveseeker_feeds_search_website_events',
#  'grooveseeker_feeds_search_websites']

# %%
tool_name = "discover_feeds"

result = await call_feed(tool_name)
result = sorted(ast.literal_eval(result))

print(result)
# Out:
# ['discover_feeds', 'search_country_counts', 'search_entities', 'search_entity_collaborations', 'search_entity_event_prices', 'search_entity_events', 'search_event_prices', 'search_events', 'search_locations', 'search_website_entities', 'search_website_events', 'search_websites']

# %%
tool_name = "search_country_counts"

result = await call_feed(tool_name)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#           country  event_count
# 0   United States         1563
# 1         Germany          486
# 2  United Kingdom          226
# 3          Canada          137
# 4           Italy           83
# 5         Romania           72
# 6         Hungary           64
# 7          France           41
# 8           India           41
# 9     Switzerland           26

# %%
tool_name = "search_entities"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#                             event_date                             entity
# 0  2026-09-30T08:45:00.000000000+00:00                 810 Sports Complex
# 1  2026-09-30T00:00:00.000000000+00:00                        Fox Theatre
# 2  2026-09-30T00:00:00.000000000+00:00                         The Chicks
# 3  2026-09-28T08:45:00.000000000+00:00                 810 Sports Complex
# 4  2026-09-27T14:00:00.000000000+00:00             Dakota Inn Rathskeller
# 5  2026-09-27T14:00:00.000000000+00:00                          Samuel KO
# 6  2026-09-26T18:00:00.000000000+00:00             West Michigan Symphony
# 7  2026-09-26T18:00:00.000000000+00:00                     The Beach Boys
# 8  2026-09-26T18:00:00.000000000+00:00                        Maris Myers
# 9  2026-09-26T18:00:00.000000000+00:00  VanDyk Mortgage Convention Center

# %%
tool_name = "search_entity_collaborations"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#    event_date                          entity  \
# 0  2026-09-30              810 Sports Complex
# 1  2026-09-30      Franke Center for the Arts
# 2  2026-09-30                  Jocelyn France
# 3  2026-09-30                     Rob Monahan
# 4  2026-09-30                     Fox Theatre
# 5  2026-09-30                      The Chicks
# 6  2026-09-28              810 Sports Complex
# 7  2026-09-28    Main Street Area Association
# 8  2026-09-28  A2 Summer Streets Music Series
# 9  2026-09-28                 Local musicians
#
#                                          event_title
# 0                                 55+ Drop-In Hockey
# 1                 Franke Center Fall Student Classes
# 2                 Franke Center Fall Student Classes
# 3                 Franke Center Fall Student Classes
# 4          Taking the Long Way 20th Anniversary Tour
# 5          Taking the Long Way 20th Anniversary Tour
# 6                                 55+ Drop-In Hockey
# ...

# %%
tool_name = "search_entity_events"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#                             event_date                             entity  \
# 0  2026-09-30T08:45:00.000000000+00:00                 810 Sports Complex
# 1  2026-09-30T00:00:00.000000000+00:00                        Fox Theatre
# 2  2026-09-30T00:00:00.000000000+00:00                         The Chicks
# 3  2026-09-28T08:45:00.000000000+00:00                 810 Sports Complex
# 4  2026-09-27T14:00:00.000000000+00:00             Dakota Inn Rathskeller
# 5  2026-09-27T14:00:00.000000000+00:00                          Samuel KO
# 6  2026-09-26T18:00:00.000000000+00:00             West Michigan Symphony
# 7  2026-09-26T18:00:00.000000000+00:00                     The Beach Boys
# 8  2026-09-26T18:00:00.000000000+00:00                        Maris Myers
# 9  2026-09-26T18:00:00.000000000+00:00  VanDyk Mortgage Convention Center
#
#                                          event_title
# 0                                 55+ Drop-In Hockey
# ...

# %%
tool_name = "search_entity_event_prices"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#                             event_date                             entity  \
# 0  2026-09-30T08:45:00.000000000+00:00                 810 Sports Complex
# 1  2026-09-28T08:45:00.000000000+00:00                 810 Sports Complex
# 2  2026-09-27T14:00:00.000000000+00:00             Dakota Inn Rathskeller
# 3  2026-09-27T14:00:00.000000000+00:00                          Samuel KO
# 4  2026-09-26T18:00:00.000000000+00:00             West Michigan Symphony
# 5  2026-09-26T18:00:00.000000000+00:00                     The Beach Boys
# 6  2026-09-26T18:00:00.000000000+00:00                        Maris Myers
# 7  2026-09-26T18:00:00.000000000+00:00  VanDyk Mortgage Convention Center
# 8  2026-09-26T18:00:00.000000000+00:00                      Funkle Jessie
# 9  2026-09-25T20:00:00.000000000+00:00                             Jo Koy
#
#                                          event_title  \
# 0                                 55+ Drop-In Hockey
# ...

# %%
tool_name = "search_event_prices"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#                             event_date  \
# 0  2026-09-30T08:45:00.000000000+00:00
# 1  2026-09-28T08:45:00.000000000+00:00
# 2  2026-09-27T14:00:00.000000000+00:00
# 3  2026-09-26T18:00:00.000000000+00:00
# 4  2026-09-25T20:00:00.000000000+00:00
# 5  2026-09-25T19:00:00.000000000+00:00
# 6  2026-09-24T19:00:00.000000000+00:00
# 7  2026-09-24T11:30:00.000000000+00:00
# 8  2026-09-23T11:30:00.000000000+00:00
# 9  2026-09-22T11:30:00.000000000+00:00
#
#                                          event_title  \
# 0                                 55+ Drop-In Hockey
# 1                                 55+ Drop-In Hockey
# 2  Oktoberfest: A Queer Afternoon at Dakota Inn R...
# 3                           Endless Summer Gala 2026
# 4                        Jo Koy Stand-Up Performance
# 5           Jalasat: A Pop-Up Performance Series #11
# 6  Tales from the Archives: President Ford & Holland
# 7                                      810 Freestyle
# ...

# %%
tool_name = "search_events"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#                             event_date  \
# 0  2026-09-30T08:45:00.000000000+00:00
# 1  2026-09-30T00:00:00.000000000+00:00
# 2  2026-09-28T08:45:00.000000000+00:00
# 3  2026-09-27T14:00:00.000000000+00:00
# 4  2026-09-26T18:00:00.000000000+00:00
# 5  2026-09-25T20:00:00.000000000+00:00
# 6  2026-09-25T19:00:00.000000000+00:00
# 7  2026-09-25T00:00:00.000000000+00:00
# 8  2026-09-24T20:00:00.000000000+00:00
# 9  2026-09-24T20:00:00.000000000+00:00
#
#                                          event_title  \
# 0                                 55+ Drop-In Hockey
# 1          Taking the Long Way 20th Anniversary Tour
# 2                                 55+ Drop-In Hockey
# 3  Oktoberfest: A Queer Afternoon at Dakota Inn R...
# 4                           Endless Summer Gala 2026
# 5                        Jo Koy Stand-Up Performance
# 6           Jalasat: A Pop-Up Performance Series #11
# 7                                          The Coney
# ...

# %%
tool_name = "search_locations"

result = await call_feed(tool_name)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#              location
# 0            A Coruña
# 1              Aachen
# 2             Aalborg
# 3               Aalen
# 4  Aalener Innenstadt
# 5               Aarau
# 6             Aarburg
# 7              Aargau
# 8              Aarhus
# 9    Abbey Brauweiler

# %%
tool_name = "search_website_entities"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#                             event_date                   website  \
# 0  2026-09-30T08:45:00.000000000+00:00      810sportscomplex.com
# 1  2026-09-30T00:00:00.000000000+00:00          bostonherald.com
# 2  2026-09-30T00:00:00.000000000+00:00          bostonherald.com
# 3  2026-09-28T08:45:00.000000000+00:00      810sportscomplex.com
# 4  2026-09-27T14:00:00.000000000+00:00          sickening.events
# 5  2026-09-27T14:00:00.000000000+00:00          sickening.events
# 6  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 7  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 8  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 9  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
#
#                               entity
# 0                 810 Sports Complex
# 1                        Fox Theatre
# 2                         The Chicks
# 3                 810 Sports Complex
# 4             Dakota Inn Rathskeller
# ...

# %%
tool_name = "search_website_events"

result = await call_feed(tool_name, location=location, start_date=start_date, end_date=end_date)

df = pd.DataFrame(ast.literal_eval(result))

df.head(10)
# Out:
#                             event_date                   website  \
# 0  2026-09-30T08:45:00.000000000+00:00      810sportscomplex.com
# 1  2026-09-30T00:00:00.000000000+00:00          bostonherald.com
# 2  2026-09-28T08:45:00.000000000+00:00      810sportscomplex.com
# 3  2026-09-27T14:00:00.000000000+00:00          sickening.events
# 4  2026-09-26T18:00:00.000000000+00:00  westmichigansymphony.org
# 5  2026-09-25T20:00:00.000000000+00:00   battlecreekenquirer.com
# 6  2026-09-25T19:00:00.000000000+00:00    arabamericanmuseum.org
# 7  2026-09-25T00:00:00.000000000+00:00        michiganpublic.org
# 8  2026-09-24T20:00:00.000000000+00:00           ticketsignup.io
# 9  2026-09-24T20:00:00.000000000+00:00           ticketsignup.io
#
#                                          event_title
# 0                                 55+ Drop-In Hockey
# 1          Taking the Long Way 20th Anniversary Tour
# 2                                 55+ Drop-In Hockey
# ...
