# %%
#!pip install spacy

# %%
import networkx as nx
import numpy as np
import pandas as pd

# %%
# for visualization
from IPython.display import SVG 
from sknetwork.visualization import svg_graph 
from sknetwork.data import Bunch 
from sknetwork.ranking import PageRank 
from scipy.sparse import csr_matrix

def draw_graph(G, show_names=False, node_size=1, font_size=10, edge_width=0.5):

    adjacency = nx.to_scipy_sparse_array(G, nodelist=None, dtype=None, weight='weight', format='csr')
    adjacency = csr_matrix(adjacency) # fix to weird sknetwork-csr issue; comment out to troubleshoot
    
    names = np.array(list(G.nodes))
    
    graph = Bunch()
    graph.adjacency = adjacency
    graph.names = np.array(names)
    
    pagerank = PageRank()
    scores = pagerank.fit_transform(adjacency)

    if show_names:
        
        image = svg_graph(graph.adjacency, font_size=font_size, node_size=node_size, names=graph.names, width=700, height=500, scores=scores, edge_width=edge_width)
    
    else:
        
        image = svg_graph(graph.adjacency, node_size=node_size, width=700, height=500, scores = scores, edge_width=edge_width)
    
    return SVG(image)

# %%
data = r'data/wikipedia_content_wilco.json'

df = pd.read_json(data)
df.head()
# Out:
#                           page  \
# 0              A Ghost Is Born
# 1           A.M. (Wilco album)
# 2    Being There (Wilco album)
# 3      Billy Bragg discography
# 4  Brewing Up with Billy Bragg
#
#                                           categories  \
# 0  [2004 albums, Album articles lacking alt text ...
# 1  [1995 debut albums, Albums produced by Brian P...
# 2  [1996 albums, Album articles lacking alt text ...
# 3  [Articles with short description, Billy Bragg,...
# 4  [1984 albums, Album articles lacking alt text ...
#
#                                              content  \
# 0  A Ghost Is Born is the fifth studio album by A...
# 1  A.M. is the debut studio album by the American...
# 2  Being There is the second studio album by the ...
# 3  The discography of British singer-songwriter B...
# 4  Brewing Up with Billy Bragg is the second albu...
#
#                                               images  \
# 0  [https://upload.wikimedia.org/wikipedia/common...
# 1  [https://upload.wikimedia.org/wikipedia/common...
# 2  [https://upload.wikimedia.org/wikipedia/common...
# 3  [https://upload.wikimedia.org/wikipedia/common...
# 4  [https://upload.wikimedia.org/wikipedia/common...
#
#                                                links  \
# 0  [A.M. (Wilco album), ARIA Charts, A Rush of Bl...
# 1  [A Ghost Is Born, Acoustic guitar, Album, AllM...
# 2  [1001 Albums You Must Hear Before You Die, A.M...
# 3  [ARIA, ARIA Charts, A New England, Alternative...
# 4  [A New England, Album, AllMusic, Andrew Collin...
#
#                                            web_links
# 0  [http://acharts.us/album/13436, http://article...
# 1  [http://articles.chicagotribune.com/1995-04-27...
# 2  [http://www.chicagorecording.com/chrisshepard/...
# 3  [http://www.billybragg.co.uk/, https://austral...
# 4  [http://hotpress.com/music/reviews/albums/4418...

# %% [markdown]
# # Methodology
#
# For this development, we only need the 'content' field. I will use spacy to do Named Entity Recognition on the combined Wilco text data, and then I will use this entity data to create an entity network. This will be fun to explore and is made entirely from text. This approach is useful on any text data.

# %%
def extract_entities(text): 

    doc = nlp(text) 

    sentences = list(doc.sents) 

    entities = [] 

    for sentence in sentences: 

        sentence_entities = [] 

        sent_doc = nlp(sentence.text) 

         

        for ent in sent_doc.ents: 

            if ent.label_ in ['PERSON', 'ORG', 'GPE']: 

                entity = ent.text.strip() 

                if "'s" in entity: 

                    cutoff = entity.index("'s") 

                    entity = entity[:cutoff] 

                if entity != '': 

                    sentence_entities.append(entity)   

        sentence_entities = list(set(sentence_entities))       

        if len(sentence_entities) > 1: 

            entities.append(sentence_entities) 

    return entities

# %%
def get_network_data(entities): 

    final_sources = [] 
    final_targets = [] 

    for row in entities: 

        source = row[0] 
        targets = row[1:] 

        for target in targets: 

            final_sources.append(source) 
            final_targets.append(target)   

    df = pd.DataFrame({'source':final_sources, 'target':final_targets}) 

    return df

# %%
import spacy

nlp = spacy.load("en_core_web_md")

# %%
text = '\n\n'.join(df['content'])

entities = extract_entities(text) 

entities
# Out:
# [['Wilco', 'Jeff Tweedy'],
#  ['Rolling Stone', 'PopMatters'],
#  ['Reprise Records', 'Wilco', 'Nonesuch Records'],
#  ['Rolling Stone', 'Foxtrot', 'The Village Voice'],
#  ['Wilco', 'Foxtrot', "Jim O'Rourke", 'Loose Fur'],
#  ['Tweedy', 'Jeff Tweedy', 'Jay Bennett', "O'Rourke"],
#  ['Phish', 'Tweedy', 'The Grateful Dead'],
#  ['Summerteeth', 'Foxtrot', 'Pro Tools'],
#  ['Tweedy', 'Pro Tools'],
#  ['Wilco', 'Mikael Jorgensen'],
#  ['Tweedy', 'John Stirratt'],
#  ['Glenn Kotche', 'Tweedy', 'Loose Fur', "Jim O'Rourke"],
#  ['Nels Cline', 'Leroy Bach', 'Wilco', 'Pat Sansone'],
#  ['John Stirratt', 'Sansone', 'The Autumn Defense'],
#  ['Chicago', 'Tweedy', 'Illinois'],
#  ['Ireland', 'Belgium', 'Sweden', 'New Zealand', 'Norway'],
#  ['the United States', 'Nielsen SoundScan'],
#  ['Jon Pareles', 'Tweedy', 'Wilco', 'Rolling Stone'],
#  ['Wilco', 'Billboard'],
#  ['PopMatters',
#   'Yankee Hotel Foxtrot',
#   'Michael Metevier',
#   'Stylus Magazine',
#   'Akiva Gottlieb'],
#  ['The A.V. Club', 'Keith Phipps'],
#  ['James Hunter', 'Wilco', 'The Village Voice'],
#  ['iPod', 'Yankee Hotel Foxtrot'],
#  ['Wilco', 'Rob Mitchum'],
#  ['Village Voice', 'Robert Christgau'],
#  ['Joshua Klein', 'the Chicago Tribune'],
#  ['Jeff Tweedy', 'US'],
#  ['Kidsmoke', 'Tweedy', 'Mikael Jorgensen'],
#  ['Kidsmoke',
#   'John Stirratt',
#   'Jorgensen',
#   'Hummingbird',
#   'Tweedy',
#   'Chris Girard',
#   'Kotche',
#   "Jim O'Rourke",
#   'Glenn Kotche',
#   'Leroy Bach',
#   'Wilco',
#   'Jeff Tweedy'],
#  ['Glenn Kotche', 'John Stirratt'],
#  ['Farfisa', 'Leroy Bach', 'Rocksichord', 'Mikael Jorgensen'],
#  ['Steve Rooke',
#   'Chris Shaw',
#   'Mike Schmelling',
#   'TJ Doherty',
#   'Haydn Johnston',
#   'Frankie Montuoro',
#   'Stan Doty',
#   'Deborah Miles Johnson',
#   'Peter Buchanan-Smith',
#   'Gladys Nilsson',
#   'Ken Waagner',
#   'Daniel Herbst',
#   "Jim O'Rourke",
#   'Mikael Jorgensen',
#   'Dan Nadel',
#   'Tim Iseler',
#   'Wilco',
#   'Matt Zivich'],
#  ['Broadway Books', 'NY', 'New York City'],
#  ['Sire Records and Reprise Records', 'Wilco'],
#  ['Wilco', 'Uncle Tupelo'],
#  ['Jay Farrar', 'Tupelo'],
#  ['Wilco', 'Brian Henneman', 'The Bottle Rockets'],
#  ['John Stirratt', 'Anodyne', 'Max Johnston', 'Ken Coomer', 'Tupelo'],
#  ['Jay Farrar', 'St. Louis', 'Missouri', 'Uncle Tupelo', 'Jeff Tweedy'],
#  ['Wilco', 'Uncle Tupelo sans Farrar'],
#  ['Anodyne', 'Tony Margherita', 'Brian Paulson'],
#  ['Wilco', 'Easley', 'Memphis', 'Tennessee'],
#  ['Tweedy', 'Stirratt', 'a Jon Spencer Blues Explosion'],
#  ['Warner Bros', 'Jeff Tweedy', 'Reprise Records'],
#  ['Tweedy', 'Wilco'],
#  ['Brian Henneman', 'The Bottle Rockets'],
#  ['Lloyd Maines', 'Daniel Corrigan'],
#  ['Howie Weinberg', 'Barbara Longo'],
#  ['Titanic Love Affair', 'Jay Bennett', 'Henneman'],
#  ['Tweedy', 'Tupelo'],
#  ['Wilco', 'Stirratt'],
#  ['Tweedy', 'Wilco', 'Stirratt'],
#  ['Uncle', 'Tweedy', 'Tupelo'],
#  ['Tweedy', 'Farrar and'],
#  ['Tweedy', 'Wilco', 'Greg Kot'],
#  ['Farrar', 'Wilco'],
#  ['Paulson', 'Warner Bros. Records', 'Trace', 'Volt'],
#  ['Warner Bros.', 'Wilco', 'Tupelo', 'Son Volt'],
#  ['Warner', 'Anodyne', 'Joe McEwen', 'Uncle Tupelo', 'Wilco'],
#  ['Richard Dodd', 'McEwen', 'Tom Petty'],
#  ['Dodd', 'Tweedy'],
#  ['Cicero', 'St. Louis', 'Tupelo'],
#  ['Austin', 'Texas', 'Wilco'],
#  ['Gram Parsons', 'Rolling Stone', 'Neil Young', 'Holly George-Warren'],
#  ['The Village Voice', 'Robert Christgau'],
#  ['The Village Voice', 'Pazz & Jop'],
#  ['Henneman', 'Volt'],
#  ['Trace', 'Billboard'],
#  ['John Stirratt', 'Jeff Tweedy - vocals'],
#  ['Lloyd Maines', 'Brian Henneman', 'Daniel Corrigan'],
#  ['Wilco', 'Daniel Corrigan', 'Brian Henneman'],
#  ['Howie Weinberg',
#   'Barbara Longo',
#   'Bob Andrews',
#   'Brian Paulson',
#   'James SK Wān - wardrobe',
#   'Greg',
#   'Daniel Corrigan',
#   'Richard Dodd',
#   'Wilco'],
#  ['Broadway Books', 'NY', 'New York City'],
#  ['Wilco', 'Reprise Records'],
#  ['Jeff Tweedy', 'Reprise Records'],
#  ['Bob Egan', 'Wilco', 'Max Johnston', 'Jay Bennett'],
#  ['Jay Farrar', 'Tweedy', 'Wilco', 'Jeff Tweedy', 'Tupelo'],
#  ['Jay Farrar', 'Trace', 'Son Volt'],
#  ['Trace', 'the Billboard Mainstream Rock Tracks'],
#  ['Tweedy', 'Wilco', 'Brian Henneman'],
#  ['Bob Andrews', 'Jay Bennett', 'Titanic Love Affair', 'Tweedy', 'Wilco'],
#  ['Uncle', 'Tweedy', 'Tupelo', 'Wilco', 'Bennett'],
#  ['Tweedy', 'Wilco'],
#  ['Tweedy', 'Farrar', 'Uncle Tupelo'],
#  ['Peter Laughner', 'Cleveland'],
#  ['Gram Parsons', 'Uncle Tupelo'],
#  ["Peter Sellers'", 'Chance'],
#  ['Joe McEwen', 'Tweedy', 'Uncle Tupelo', 'Warner Brothers'],
#  ['Tweedy', 'McEwen', 'Howie Klein', 'Reprise Records'],
#  ['Freakwater', 'Bob Egan', 'Wilco'],
#  ['Egan', 'Freakwater', 'Wilco'],
#  ['Max Johnston', 'Bennett'],
#  ['Ken Coomer', 'John Stirratt'],
#  ['Greg Kot', 'Rolling Stone'],
#  ['Jeff Tweedy', 'Robert Christgau'],
#  ['Ryan Schreiber', 'Wilco'],
#  ['The Village Voice', 'Pazz & Jop'],
#  ['John Stirratt',
#   'Jay Bennett',
#   'Max Johnston',
#   'Bob Egan',
#   'Ken Coomer',
#   'Wilco',
#   'Jeff Tweedy',
#   'Greg Leisz'],
#  ['Gary Grant', 'Jerry'],
#  ['Jessy Greene', 'Dan Higgins'],
#  ['Jim Scott',
#   'Dahn Davis',
#   'Skip Bryant',
#   'Brad Miller',
#   'Lou Whitney',
#   'Mike Scotella',
#   'Bob Ludwig',
#   'Greg',
#   'Jim Rondinelli',
#   'Ron Lowe',
#   'Martin Stebbing',
#   'Chris Shepard',
#   'Skip Saylor'],
#  ['Broadway Books', 'NY', 'New York City'],
#  ['Billy Bragg', 'Wilco'],
#  ['Billy Bragg', 'Bragg'],
#  ['Allen', 'Woody Allen', 'Contemporary Mores'],
#  ['Smiths', 'Johnny Marr'],
#  ['James Brown', 'George Terry'],
#  ['Keith Richards', 'Morrissey', 'Johnny Marr', 'Mick Jagger'],
#  ['Florence Reece,', 'Bragg'],
#  ['Billy Bragg',
#   'Tim Young',
#   'Edward de Bono',
#   'Kenny Craddock',
#   'Kenny Jones',
#   'Heeps Willard - cover',
#   'Dave Woodhead',
#   'Wilco',
#   'Duncan Cowell'],
#  ['Tweedy', 'Sky Blue Sky', 'Cruel Country'],
#  ['Wilco', 'Jeff Tweedy'],
#  ['Tweedy', 'United States'],
#  ['Substack', 'Tweedy', 'Wilco'],
#  ['Wilco', 'Cruel Country'],
#  ['Jon Pareles', 'Cruel Country Wilco', 'The New York Times'],
#  ['Nels Cline',
#   'John Stirratt',
#   'Jennifer Kummer',
#   'Mikael Jorgensen',
#   'Pat Sansone',
#   'Glenn Kotche',
#   'Wilco',
#   'Jeff Tweedy'],
#  ['Lawrence Azerrad',
#   'United States',
#   'Illinois',
#   'Tom Schick',
#   'Mark Greenberg',
#   'Bob Ludwig',
#   'Roselle',
#   'Teddy Morgan',
#   'Glenn Kotche',
#   'Wilco'],
#  ['Kotche', 'Wilco', 'Introducing'],
#  ['Edith Frost', 'Wilco', "Jim O'Rourke"],
#  ['Loose Fur', "O'Rourke", 'Kotche', 'Jeff Tweedy', 'O’Rourke'],
#  ['Kotche', 'Wilco', 'Yankee Hotel Foxtrot'],
#  ['Chicago', 'Sky Blue Sky', 'Wilco'],
#  ['Chris Corsano',
#   'Fillmore',
#   'Nickel Creek',
#   'David Cossin',
#   'Darin Gray',
#   'Kotche',
#   'Tim Barnes',
#   'Fred Lonberg-Holm',
#   'Wilco'],
#  ['Kotche', 'the Kronos Quartet'],
#  ['Drumkit Quartets', 'Meet the Composer'],
#  ['Mobile', 'Wilco'],
#  ['Chicago', 'Kotche', 'Eighth Blackbird'],
#  ['Bill Santen', 'Kotche', 'Portland'],
#  ['Kotche', 'Birddog'],
#  ['Paul K.Circa', 'Birddog', 'Kotche', 'Elliott Smith', 'Trackhouse', 'Reach'],
#  ['the University of Kentucky', 'Roselle', 'IL'],
#  ['Illinois', 'The Cavaliers Drum and Bugle Corps', 'Glenn', 'Rosemont'],
#  ['UK', 'College of Fine Arts'],
#  ['Glenn Kotche', 'Drumkit Quartets', 'Wilco'],
#  ['Chicago', 'Sky Blue Sky'],
#  ['Fillmore', 'Fillmore Wooden Box Set'],
#  ['Wilco', 'USA'],
#  ['Fred Katz', 'Lonberg-Holm Quartet'],
#  ['Paul K & The Weathermen - "Love', 'Simon Joyner'],
#  ["Jim O'Rourke - Halfway", 'Threeway'],
#  ["Ed O'Brien", 'John Luther Adams - Ilimaq'],
#  ['Billy Bragg', 'Grant Cunliffe', 'Smiths', 'Moodswings'],
#  ['Billy Bragg', 'Bragg'],
#  ['Billy Bragg', 'Mermaid Avenue Vols 1 & 2', 'Gold Records'],
#  ['José Gross',
#   "Mark Perrys'",
#   'Here & Now',
#   'Blank Space',
#   'Street-Level Studio with Kif Kif'],
#  ['Androids Of Mu',
#   'The Instant Automatons & Take',
#   'Fuck Off Records',
#   'DIY',
#   'World Domination Enterprises',
#   'Brian Brain'],
#  ['Rough Trade Showbiz', 'Smiths'],
#  ['Kazuko Hohki', 'Frank Chickens'],
#  ['Bloke\nMermaid Avenue Vol',
#   'Billy Bragg',
#   'William Bloke\nBloke',
#   'Wilco & Natalie Merchant'],
#  ['Johnny Clash', 'England', 'Love & Justice'],
#  ['Shakespeare', 'Sister\nMeat Is Murder\nWork Is A'],
#  ['Sam Jones', 'Wilco'],
#  ['the United States', 'Cowboy Pictures'],
#  ['Wilco', 'the Warner Music Group'],
#  ['Wilco', 'Reprise'],
#  ['Wilco', 'Nonesuch Records'],
#  ['Warner Music Group', 'Wilco'],
#  ['Tweedy', 'Jeff Tweedy', 'Jay Bennett'],
#  ['Tony Margherita',
#   'Jay Bennett',
#   'the United States',
#   'Glenn Kotche',
#   'John Stirratt\nLeroy Bach',
#   'Jeff Tweedy',
#   'the Los Angeles Film Festival'],
#  ['The A.V. Club', 'Scott Tobias', 'Sam Jones'],
#  ['Billboard', 'Chris Morris', 'Plexifilm'],
#  ['Yankee Hotel Foxtrot',
#   'David Fricke',
#   'Rolling Stone',
#   'Sam Jones',
#   'Wilco'],
#  ['Jay Farrar',
#   'Gob Iron',
#   'Jay Bennett',
#   'Uncle Tupelo',
#   'Bob Dylan',
#   'Jeff Tweedy'],
#  ['Jay Farrar', 'Jeff Tweedy', 'Tupelo', 'Mike Heidorn'],
#  ['John Stirratt', 'Farrar, Tweedy', 'Max Johnston', 'Ken Coomer', 'Tupelo'],
#  ['Jim Boquist', 'Farrar, Heidorn', 'Dave Boquist'],
#  ['Farrar',
#   'Chris Masterson',
#   'Dave Bryson',
#   'Andrew Duplantis',
#   'Derry De Borja'],
#  ['Jeffrey Scot Tweedy', 'Gob Iron', 'Wilco', 'Anders Parker'],
#  ['Uncle',
#   'Jay Farrar',
#   'Belleville',
#   'Illinois',
#   'Tweedy',
#   'Plebes',
#   'Tupelo'],
#  ['Tweedy', 'Wilco', 'Tupelo', 'Yankee Hotel Foxtrot'],
#  ['Billy Bragg', 'Spencer', 'Tweedy', 'Wilco', 'Tupelo'],
#  ['Belleville',
#   'Illinois',
#   'née Werkmeister',
#   'Bob',
#   'Tweedy',
#   'JoAnn Tweedy'],
#  ['Alton & Southern Railroad', 'Bob Tweedy', 'East St. Louis', 'JoAnn'],
#  ['Debbie Voll', 'Tweedy', 'Steven Tweedy', 'Greg Tweedy'],
#  ['Jay Farrar', 'Tweedy'],
#  ['Farrar', 'Tweedy'],
#  ['Edwardsville',
#   'Belleville Area College',
#   'Tweedy',
#   'Southern Illinois University'],
#  ['Tweedy', 'Plebes', 'Dade Farrar', 'Wade'],
#  ['Tweedy', 'Plebes', 'Dade Farrar'],
#  ['Wade Farrar', 'Jay Farrar', 'Tweedy', 'Mike Heidorn'],
#  ['Wade Farrar', 'Southern Illinois University'],
#  ['Farrar', 'Heidorn', 'Tweedy', 'Wade', 'Tupelo'],
#  ['Tweedy', 'Tupelo'],
#  ['St. Louis', 'Tweedy', 'Tony Margherita', 'Euclid Records'],
#  ['Cicero', 'Washington University', 'St. Louis'],
#  ['Giant/Rockville Records', 'Tupelo'],
#  ['Farrar',
#   'Mark Ortmann',
#   'Brian Henneman',
#   'Coffee Creek',
#   'Tweedy',
#   'Tupelo',
#   "The Bottle Rockets'"],
#  ['Farrar', 'Tweedy'],
#  ['Tweedy', 'Henneman'],
#  ['Tweedy', 'Sue Miller'],
#  ['Warner', 'Sire Records', 'Tupelo', 'Rockville'],
#  ['John Stirratt',
#   'Anodyne',
#   'Billboard Heatseekers',
#   'Max Johnston',
#   'Ken Coomer',
#   'Bill Belzer',
#   'Mike Heidorn',
#   'Tupelo'],
#  ['Tweedy', 'Farrar', 'Tony Margherita'],
#  ['Farrar', 'Tweedy'],
#  ['Tweedy', 'Farrar', 'Tupelo'],
#  ['Farrar',
#   "Conan O'Brien",
#   'Jim Boquist',
#   'Dave Boquist',
#   'Son Volt',
#   '80–84\u200a Farrar',
#   'Tweedy',
#   'Mike Heidorn'],
#  ['John Stirratt',
#   'Johnston',
#   'Coomer',
#   'Max Johnston',
#   'Tweedy',
#   'Stirratt',
#   'Ken Coomer',
#   'Wilco',
#   'Jeff Tweedy'],
#  ['Sky Blue Sky', 'Wilco'],
#  ['Tweedy', 'Golden Smog and'],
#  ['Wilco', 'Reprise/Warner Bros. Records'],
#  ['Tweedy', '89–91', 'Jay Bennett'],
#  ['Trace', 'Heatseekers', 'Volt'],
#  ['Marc Perlman',
#   'Jayhawks',
#   'Noah Levy',
#   'Gary Louris',
#   'Tweedy',
#   'Honeydogs',
#   'Soul Asylum',
#   'Dan Murphy',
#   'Kraig Johnson'],
#  ['Tweedy', 'Scott Summit', 'Golden Smog'],
#  ['Tweedy', 'Wilco'],
#  ['William H. Gass', 'Tweedy', 'John Fante', 'Henry Miller'],
#  ['Summerteeth', 'A&R', 'Wilco'],
#  ['Summerteeth', 'Billy Bragg', 'Tweedy', 'Woody Guthrie'],
#  ['Tweedy', 'Bragg', 'Jay Bennett'],
#  ['Tweedy', 'Wilco', 'Bragg'],
#  ['Chicago', 'Jeff Tweedy'],
#  ['Tweedy', "Jim O'Rourke", "O'Rourke"],
#  ['Glenn Kotche', 'Loose Fur', "O'Rourke"],
#  ['Tweedy', 'Wilco', 'Loose Fur', 'Yankee Hotel Foxtrot'],
#  ['Ken Coomer', 'Tweedy', 'Kotche'],
#  ['Tweedy', 'Jay Bennett'],
#  ['Tweedy', 'Bennett', "O'Rourke"],
#  ['Tweedy', 'Wilco', 'Bennett'],
#  ["Reprise Records'", 'America Online', 'Time Warner'],
#  ['AOL Time Warner', 'Howie Klein', 'Wilco', 'Reprise Records'],
#  ['A&R', 'Wilco', 'David Kahne', 'the Yankee Hotel Foxtrot'],
#  ['Gary Briggs', 'the Chicago Tribune'],
#  ['Wilco', 'Warner Brothers'],
#  ['Tweedy', 'Wilco'],
#  ['Wilco', 'Warner Brothers', 'Nonesuch Records'],
#  ['AOL Time Warner', 'Wilco'],
#  ['the Recording Industry Association of America', 'Jeff Tweedy'],
#  ['Scott McCaughey', 'Tweedy'],
#  ['Tweedy', 'McCaughey'],
#  ['Wilco', 'Down'],
#  ['Chicago', 'The Vic Theater'],
#  ['Sky Blue Sky', 'Wilco'],
#  ['Tweedy', 'Wilco', 'Jay Bennett'],
#  ['Schmilco', 'Wilco'],
#  ['Tweedy', 'Records'],
#  ['Humboldt State University',
#   'Seattle',
#   'Fillmore',
#   'Portland',
#   'San Francisco',
#   'Tweedy',
#   'Arcata',
#   'Moore Theater',
#   'McDonald Theatre',
#   'Eugene'],
#  ['Christoph Green', 'Fugazi', 'Brendan Canty'],
#  ['Tweedy', 'Mavis Staples'],
#  ['Chicago', 'Tweedy', 'Corsicana Lemonade', 'Wilco', 'White Denim'],
#  ['Tweedy', 'The Loft Studios'],
#  ['Portlandia', 'Tweedy', 'Parks and Recreation'],
#  ['Tweedy', 'Spencer'],
#  ['Sukierae', 'Spencer'],
#  ['Uncle', 'Tweedy', 'Wilco', 'Tupelo'],
#  ['Wilco, Loose Fur', 'Jeff Tweedy'],
#  ['Susan Tweedy', 'Jeff', 'Instagram'],
#  ['Neil Young', 'Tweedy'],
#  ['Tweedy', 'London', 'Rolling Stone', 'Clash'],
#  ['Tweedy', 'Belleville'],
#  ['Jason & the Scorchers', 'Tupelo'],
#  ['Tweedy', 'Wilco', 'Tupelo'],
#  ['Tweedy', "Jim O'Rourke", 'Yankee Hotel Foxtrot'],
#  ['Tweedy', 'Gibson', 'Gibson SG Standard', 'an Epiphone Casino'],
#  ['Maestro', 'Custom Shop Vintage Original Spec', 'Custom Shop'],
#  ['John Stirratt', 'Tweedy'],
#  ['Chicago', 'Tweedy', 'Irving Park', 'Sue Miller'],
#  ['Uncle', 'Cubby Bear', 'Miller', 'Tweedy', 'Tupelo'],
#  ['Uncle', 'Lounge Ax', 'Miller', 'Chicago', 'Tupelo'],
#  ['Miller', 'Tweedy', 'Sue'],
#  ['Tweedy', 'Rolling Stone'],
#  ['Sam', 'Spencer'],
#  ['Blisters', 'Spencer'],
#  ['Neil Young', 'Wilco', 'Spencer'],
#  ['Tweedy', 'Bob Dylan'],
#  ['Tweedy', 'Irving Park'],
#  ['Anodyne', 'Tupelo'],
#  ['Summerteeth', 'Yankee Hotel Foxtrot'],
#  ['Jeff', 'Tweedy'],
#  ['Jeff', 'Tweedy', 'Narrator'],
#  ['Bardo', 'Lincoln'],
#  ['Tweedy', 'ASIN', 'Jeff'],
#  ['Wilco', 'Dutton Books', 'Discording with'],
#  ['Jeff', 'Tweedy'],
#  ['Wilco\nWilco:', 'Daniel Nadel', 'Tupelo\nWilco', 'Peter', 'Buchanan-Smith'],
#  ['Broadway Books', 'New York'],
#  ['New York Public Library',
#   'Steven Johnson',
#   'Jeff Tweedy',
#   'Lawrence Lessig'],
#  ['Community Audio', 'Internet Archive'],
#  ['Wilco', 'Jeff Tweedy', 'Uncle Tupelo'],
#  ['Tweedy', 'Wilco', 'The Autumn Defense', 'John Chadwick Stirratt'],
#  ['Louisiana', 'Stirratt', 'Mandeville'],
#  ['Phi Kappa Tau', 'the University of Mississippi', 'Mandeville High School'],
#  ['Laurie Stirratt', 'Mississippi', 'Cary Hudson', 'Oxford'],
#  ['Uncle', 'Tupelo'],
#  ['Lafayette', 'Bluerunners', 'Louisiana', 'Stirratt', 'Tupelo'],
#  ['Max Johnston', 'Stirratt', 'Ken Coomer', 'Wilco', 'Jeff Tweedy', 'Tupelo'],
#  ['Tweedy', 'Wilco', 'Stirratt'],
#  ['Jay Bennett', 'Courtesy Move', 'Stirratt', 'Ken Coomer', 'Wilco'],
#  ['New Orleanian', 'The Autumn Defense', 'Stirratt', 'Pat Sansone'],
#  ['Uncle',
#   'John Stirratt',
#   'Wikimedia Commons\nThe Autumn Defense',
#   'Ken Coomer',
#   'Wilco',
#   'Tupelo'],
#  ['Nashville', 'Clockhammer'],
#  ['Vaquero', 'Coomer', 'Chetes'],
#  ['Coomer', 'Yankee Hotel Foxtrot', 'Summerteeth', 'Horas Perdidas', 'Wilco,'],
#  ['Emmylou Harris',
#   'Sons of Bill',
#   'Steve Earle',
#   'Coomer',
#   'Toy Horses',
#   'Tim Finn',
#   'Will Hoge',
#   'Malcolm Holcombe',
#   'Josh Hoyer',
#   'Arlo McKinley',
#   'Frontier Ruckus'],
#  ['Nashville', 'Tennessee'],
#  ['Chicago', 'Wilco', 'Nonesuch Records'],
#  ['Chicago', 'Vic Theater'],
#  ['Nels Cline', 'Pat Sansone'],
#  ['The A.V. Club and', 'Pitchfork', 'Yankee Hotel Foxtrot'],
#  ['Day Wilco', 'Kicking Television'],
#  ['Leroy Bach', 'Wilco'],
#  ['Nels Cline', 'Pat Sansone'],
#  ['Summerteeth', 'Yankee Hotel Foxtrot'],
#  ['Chicago', 'Wilco'],
#  ['Chicago', 'Illinois', 'The Vic Theater'],
#  ['Wilco', 'Records', 'Yankee Hotel Foxtrot'],
#  ['John Stirratt', 'Jeff Tweedy'],
#  ['Nels Cline', 'Wilco', 'Pat Sansone'],
#  ['Glenn Kotche', 'Mikael Jorgensen'],
#  ['Rick Parenti', 'Patrick Newbery', 'Nick Broste'],
#  ['Scott Tobias', 'The A.V. Club'],
#  ['Wilco', 'Mark Deming'],
#  ['Pitchfork', 'Marc Hogan'],
#  ['Wilco', 'Billboard'],
#  ['Ben Gilbert', 'Yahoo'],
#  ['Tweedy', 'Pitchfork', 'Hogan'],
#  ['Stylus Magazine', 'Andrew Gaering'],
#  ['John Stirratt',
#   'Yankee Hotel Foxtrot',
#   'Summerteeth',
#   'Jay Bennett',
#   'Tweedy',
#   'Mikael Jorgensen'],
#  ['Glenn Kotche', 'Tweedy'],
#  ['Tweedy', 'Bennett', 'Yankee Hotel Foxtrot'],
#  ['Summerteeth', 'Hummingbird'],
#  ['Kidsmoke',
#   'Yankee Hotel Foxtrot',
#   'Charles Wright',
#   'Tweedy',
#   '6:13',
#   'Woody Guthrie',
#   'Yusef Rahman',
#   'Bennett'],
#  ['Yankee Hotel Foxtrot',
#   'Summerteeth',
#   'Guthrie, Bragg',
#   'Jorgensen',
#   'Tweedy',
#   'Chris Girard',
#   'The SpongeBob SquarePants Movie: Music From the Movie',
#   'Spencer Tweedy',
#   'iTunes',
#   'Jeff Tweedy',
#   'Bennett'],
#  ['Glenn Kotche',
#   'Stan Doty',
#   'Nathan Baker',
#   'Michael Ways',
#   'Zoran Orlic',
#   'Mike Segal',
#   'Rick Parenti',
#   'Karina Benznicki',
#   'Patrick Newbery',
#   'Mikael Jorgensen',
#   'Timothy Powell',
#   'Dan Glomski',
#   'Jeff Tweedy',
#   'Matt Zivich',
#   'John Stirratt',
#   'Chris Hoffman',
#   'Mycle Konopka',
#   'Nick Webb',
#   'Deborah Miles Johnson',
#   'Pat Sansone',
#   'Nick Broste',
#   'Jim Scott',
#   'Frankie Montuoro',
#   'Eli Cane',
#   'Nels Cline'],
#  ['Chicago', 'Billy Bragg', 'Metacritic\n\nLife'],
#  ['Kirsty MacColl', 'the UK', 'Albums Chart'],
#  ['Spy vs Spy', 'Bragg', 'Mad'],
#  ['Billy Bragg', 'Brewing Up'],
#  ['Richard', 'Billy Bragg', 'Bragg', 'Bobby Troup'],
#  ['Richard', 'John Cale'],
#  ['Billy Bragg', 'Dave Woodhead'],
#  ['Grant Showbiz', 'Tim Young'],
#  ['Wiggy', 'Duncan Cowell', 'Steve Goldstein'],
#  ['London', 'Virgin Books'],
#  ['Billy Bragg',
#   'Glenn Kotche',
#   "Jim O'Rourke",
#   'Sonic Youth',
#   'Wilco',
#   'Jeff Tweedy'],
#  ['Chicago', 'Tweedy'],
#  ['Tweedy', "O'Rourke"],
#  ['Kotche', "O'Rourke"],
#  ['Drag City', 'Loose Fur'],
#  ['Sky Blue Sky', 'Kotche', 'Wilco', "O'Rourke"],
#  ['Wilco', 'Jeff Tweedy', "Jim O'Rourke"],
#  ['Tweedy', "O'Rourke"],
#  ['Chicago', 'Tweedy'],
#  ['Tweedy', "O'Rourke"],
#  ['Phil Niblock', 'Chicago', 'Roy Harper', 'T. Rex', 'Wilco'],
#  ['Glenn Kotche', "O'Rourke"],
#  ['TV Guide', 'Tweedy'],
#  ['Wilco', 'Jeff Tweedy'],
#  ['Tweedy', "Utah Phillips'", 'Natalie Merchant'],
#  ['Tweedy', 'Wilco'],
#  ['Wilco', 'Yankee Hotel Foxtrot'],
#  ['Summerteeth', 'Tweedy', 'Wilco'],
#  ['Ken Coomer', 'Wilco', 'Coomer'],
#  ['Wilco', 'Jay Bennett', 'Coomer'],
#  ['Loose Fur', 'Coomer', 'Tweedy', 'Glenn', 'Wilco'],
#  ['Kotche', 'Coomer'],
#  ['Glenn', 'Bennett'],
#  ['Tweedy', 'Coomer'],
#  ['Tweedy', 'Bennett'],
#  ['Tweedy', "Jim O'Rourke", 'Bennett'],
#  ['Bennett', "O'Rourke"],
#  ['Wilco', "O'Rourke"],
#  ['Tweedy', 'Kotche', 'Loose Fur'],
#  ['Wilco', 'Loose Fur'],
#  ['Brooklyn', 'Tweedy', 'NY'],
#  ['Glenn Kotche', 'Sky Blue Sky', 'Wilco', "Jim O'Rourke"],
#  ['Broadway Books', 'NY', 'New York City'],
#  ['the Billy Bragg & Wilco Mermaid Avenue', 'Woody Guthrie', 'Sand'],
#  ['Nora Guthrie', 'Billy Bragg', 'Woody Guthrie'],
#  ['Guthrie', 'Bragg', 'Jay Bennett', 'Wilco', 'Jeff Tweedy'],
#  ['Texas',
#   'Bragg',
#   'New York City',
#   'California',
#   'Oklahoma',
#   'Nora',
#   'Woody Guthrie',
#   'Pampa',
#   'Okemah'],
#  ['Bragg', 'Boston', 'Natalie Merchant', 'Chicago', 'Dublin', 'Wilco'],
#  ['Guthrie',
#   'Billy Bragg',
#   'Words & Music',
#   'Jay Bennett',
#   'Woody Guthrie',
#   'Jeff Tweedy'],
#  ['Guthrie',
#   'Music: Bragg',
#   'Bragg',
#   'Words & Music',
#   'Ingrid Bergman',
#   'Corey Harris'],
#  ['Guthrie', 'Music: Bragg/Tweedy/Bennett'],
#  ['Guthrie', 'Tweedy', 'Music: Bragg', 'Bragg'],
#  ['Guthrie',
#   'Music: Bragg',
#   'Bragg',
#   'Tweedy',
#   'Guest"(All',
#   'Guthrie &',
#   'Wilco/Bragg/'],
#  ['Billy Bragg', 'Wilco', 'Woody Guthrie'],
#  ['Nora Guthrie', 'Guthrie'],
#  ['Woody', 'Elisha A. Hoffman'],
#  ['Wilco', 'Bragg'],
#  ['Leslie',
#   'Billy Bragg',
#   'Farfisa',
#   'John Stirratt',
#   'Eliza Carthy',
#   'Delayaphone',
#   'Mellotron',
#   'Jay Bennett',
#   'Natalie Merchant',
#   'B3',
#   'WurlitzerAdditional',
#   'Corey Harris',
#   'Ken Coomer',
#   'Leroy Bach',
#   'Jeff Tweedy',
#   'Mike Henry'],
#  ['Wayback Machine\nMermaid Avenue Vol', 'Metacritic\n\nMermaid Avenue'],
#  ['Woody Guthrie', 'Billy Bragg & Wilco'],
#  ['Guthrie', 'Nonesuch Records on Record Store Day'],
#  ['Billy Bragg',
#   'John Stirratt',
#   'Ben Ivitsky',
#   'Carthy',
#   'Peter Yanowitz',
#   'Jay Bennett',
#   'Natalie Merchant',
#   'Bob Egan',
#   'Corey Harris',
#   'Ken Coomer',
#   'Jeff Tweedy'],
#  ['Billy Bragg',
#   'Metacritic\n\nMermaid Avenue',
#   'Woody Guthrie',
#   'Wilco',
#   'Nonesuch Records\nMermaid Avenue'],
#  ['Nora Guthrie', 'Guthrie', 'the Woody Guthrie Foundation'],
#  ['Guthrie', 'Coney Island', 'New York'],
#  ['American Songwriter Magazine', 'Woody Guthrie'],
#  ['Guthrie', 'Billy Bragg', 'Bragg', 'New York City', 'Nora', 'Woody Guthrie'],
#  ['Nora Guthrie', 'Wilco', 'Bragg'],
#  ['Wilco', 'Ireland', 'Bragg'],
#  ['Guthrie', 'Wilco', 'Bragg'],
#  ['Best Contemporary Folk Album', 'the Pazz & Jop Critics'],
#  ['Billy Bragg', 'Wilco'],
#  ['Guthrie', 'Bob Dylan', 'Woody Guthrie', 'Margie'],
#  ['Guthrie', 'Dylan', 'Margie', 'Arlo'],
#  ['Dylan', 'New York'],
#  ['Billy Bragg', 'Wilco', 'Dylan'],
#  ['Nora', 'Woody'],
#  ['Farfisa', 'Billy Bragg', 'Jay Bennett', 'National', 'Hammond B-3'],
#  ['John Stirratt',
#   'Johnathan "JP" Parker',
#   'Ken Coomer',
#   'Hammond B-3',
#   'Jeff Tweedy',
#   'Eliza Carthy'],
#  ['Corey Harris', 'Elizabeth Steen', 'Peter Yanowitz'],
#  ['Bob Egan', 'Natalie Merchant'],
#  ['Belleville', 'Illinois', 'Son Volt', 'Mike Heidorn', 'Tupelo'],
#  ['Jay Farrar',
#   'Brian Henneman',
#   'Coffee Creek',
#   'The Bottle Rockets',
#   'Jeff Tweedy',
#   'Tupelo'],
#  ['Heidorn', 'Farrar', 'Tupelo'],
#  ['Buck', 'Belleville', 'Tupelo'],
#  ['dBpm Records', 'Wilco'],
#  ['Chicago', 'Wilco'],
#  ['Glenn Kotche', 'Jeff Tweedy'],
#  ['Guardian', 'Michael Hann'],
#  ['Zoran Orlic',
#   'Lawrence Azerrad',
#   'John Stirratt',
#   'Paul Von Mertens',
#   'Mark Greenberg',
#   'Tom Schick',
#   'Bob Ludwig',
#   'Mikael Jorgensen',
#   'Pat Sansone',
#   'Glenn Kotche',
#   'Wilco\n\nNels Cline',
#   'Jeff Tweedy'],
#  ['Chicago', 'dBpm Records', 'Wilco'],
#  ['Wilco', 'Jeff Tweedy'],
#  ['Chicago', 'Tweedy'],
#  ['Schmilco', 'Wilco'],
#  ['Nilsson Schmilsson', 'Harry Nilsson'],
#  ['Joan Cornellà', 'Stefania Lusini'],
#  ['Schmilco', 'Metacritic'],
#  ['John Stirratt',
#   'Glenn Kotche',
#   'Mark Greenberg',
#   'Joan Cornellà',
#   'Tom Schick',
#   'Bob Ludwig',
#   'Mikael Jorgensen',
#   'Pat Sansone',
#   'Nels Cline',
#   'Wilco',
#   'Jeff Tweedy'],
#  ['Sky Blue Sky', 'Wilco', 'Nonesuch Records'],
#  ['Nashville', 'Tennessee', 'Nels Cline', 'Pat Sansone'],
#  ['Sky Blue Sky', 'Wilco'],
#  ['PopMatters and Rolling Stone', 'Pitchfork'],
#  ['Glenn Kotche', 'Pitchfork'],
#  ['Jeff Tweedy', 'Nonesuch Records'],
#  ['Tweedy', 'Sky Blue Sky', 'Belleville', 'Illinois'],
#  ['TJ Doherty', 'USA', 'Chicago', 'Tweedy', 'Irving Park', 'Wilco'],
#  ['Beatles', 'Billboard', 'The Beach Boys'],
#  ['Sky Blue Sky', "Jim O'Rourke"],
#  ['The Byrds and Fairport Convention', 'Tweedy'],
#  ['Chicago', 'The Vic Theater'],
#  ['Tweedy', 'Sky Blue Sky', 'Wilco'],
#  ['Tweedy', 'Sky Blue Sky', 'Pro Tools'],
#  ['John Stirratt', 'Jeff Tweedy'],
#  ['Glenn Kotche', 'Mikael Jorgensen'],
#  ['Nels Cline', 'Pat Sansone'],
#  ['Karen Waltuch', "Jim O'Rourke"],
#  ['PLYRZ Studios', 'Jim Scott', 'California', 'Santa Clarita'],
#  ['Sky Blue Sky', 'Manuel Presti'],
#  ['Rome', 'Presti', 'Italy'],
#  ['Lawrence Azerrad', 'Jeff Tweedy'],
#  ['Sky Blue Sky', 'Wilco'],
#  ['Sky Blue Sky', 'Wilco'],
#  ['Wilco', 'Jeff Tweedy', 'Apple Computer', 'Telefónica Moviles'],
#  ['Crispin Porter', 'Bogusky'],
#  ['the United Kingdom',
#   'Belgium',
#   'Switzerland',
#   'Denmark',
#   'Spain',
#   'Italy',
#   'Norway'],
#  ['Germany',
#   'Ireland',
#   'the United Kingdom',
#   'Sky Blue Sky',
#   'Belgium',
#   'Sweden',
#   'Australia',
#   'New Zealand',
#   'Norway'],
#  ['Peter Green-era',
#   'Rolling Stone',
#   'Fleetwood Mac',
#   'Television',
#   'Rob Sheffield',
#   'Wilco',
#   'Impossible Germany'],
#  ['Wilco', 'Mark Deming'],
#  ['Wilco', 'Stutz of Filter'],
#  ['Los Angeles Times', 'Richard Cromelin'],
#  ['Wilco', 'Andrew C. Bradick', 'Prefix Magazine'],
#  ['Wilco', 'Alan Shulman'],
#  ['iPod', 'Tiny Mix Tapes'],
#  ['Sky Blue Sky', 'Slant Magazine', 'Jonathan Keefe', 'Wilco'],
#  ['Tweedy', 'Beatles', 'Graeme Thomson'],
#  ['Wilco', 'The New York Times'],
#  ['The Boston Globe', 'Joan Anderman'],
#  ['Chicago', 'Stylus Magazine', 'Ian Cohen'],
#  ['Guardian', 'Dorian Lynskey', 'Sky Blue Sky', 'Neil Young or Television'],
#  ['Tweedy', 'Rob Mitchum', 'Pitchfork'],
#  ['Nels Cline', 'Billboard', 'Jeff Tweedy'],
#  ['Wilco', 'John Walshe', 'Hot Press'],
#  ['Wilco', 'PopMatters', 'Michael Metevier'],
#  ['Rob Sheffield', 'Sky Blue Sky', 'Wilco'],
#  ['Doug Freeman',
#   'The Austin Chronicle',
#   'Tweedy',
#   'Dusted Magazine',
#   'Brandon Kreitler'],
#  ['The A.V. Club', 'Sky Blue Sky', 'Billboard, Paste, Uncut'],
#  ['Sam Sodomsky', 'Pitchfork'],
#  ['Lead Electric Guitar',
#   'Electric Guitar',
#   'Lap Steel Guitar',
#   'Loops',
#   'Lead Electric'],
#  ['Pat Sansone',
#   'Electric Guitar',
#   'John Stirratt',
#   'Chamberlin',
#   'Piano',
#   'Mellotron',
#   'String Arrangements',
#   'Wurlitzer',
#   'Backing Vocals',
#   'Mikael Jorgensen',
#   'Glockenspiel',
#   'Bass',
#   'Glenn Kotche',
#   'Hammond B3 Organ',
#   'Hammond A100 Organ',
#   'Jeff Tweedy'],
#  ['Jim Scott',
#   'Viola',
#   'TJ Doherty',
#   'Jason Tobias',
#   'Robert Ludwig',
#   'Violin',
#   'Tom Gloady',
#   'Manuel Presti',
#   'Frack Ockenfels',
#   'Kevin Dean',
#   'Greg',
#   'Nathaniel Murphy',
#   'Karen Waltuch',
#   'Azerrad'],
#  ['Broadway Books', 'NY', 'New York City'],
#  ['Wilco', 'Rolling Stone', 'Jeff Tweedy'],
#  ['Stephen Colbert', 'George Lucas', 'Jeff Tweedy'],
#  ['McDonald', 'Wilco'],
#  ['Billboard 200', 'Top Rock Albums'],
#  ['Nels Cline',
#   'Scott McCaughey',
#   'Tweedy',
#   'Mikael Jorgensen',
#   'Glenn Kotche',
#   'Jeff Tweedy'],
#  ['Nels Cline',
#   'John Stirratt',
#   'Sukierae',
#   'Spencer',
#   'Mellotron',
#   'Scott McCaughey',
#   'Tweedy',
#   'Mikael Jorgensen',
#   'Spencer Tweedy',
#   'Patrick Sansone',
#   'Glenn Kotche',
#   'Wilco',
#   'Jeff Tweedy'],
#  ['Low, White Denim', 'Mavis Staples', 'Jeff Tweedy'],
#  ['Tweedy', 'Spencer'],
#  ['Lucius', 'Sukierae', 'Scott McCaughey', 'Jess Wolfe', 'Holly Laessig'],
#  ['Tweedy', 'Wilco'],
#  ['Wilco', 'Sukierae'],
#  ['Tweedy', 'Wilco'],
#  ['Guardian', 'Tweedy'],
#  ['dBpm Records', 'Wilco'],
#  ['Liam Cunningham', 'Darin Gray', 'Jeff', 'Spencer Tweedy', 'Jim Elkington'],
#  ['Tweedy', 'Sukierae'],
#  ['Wilco', 'Uncle Tupelo', 'Sukierae'],
#  ['Wilco', 'Jeff Tweedy'],
#  ['Boyhood', 'Richard Linklater'],
#  ['Stereogum', 'SoundCloud'],
#  ['VH1', 'Tweedy'],
#  ['Electric Sitar',
#   'Piano',
#   'Cassette',
#   'Mellotron',
#   'Keyboard',
#   'Bass',
#   'Jeff Tweedy'],
#  ['Jess Wolfe', '2,5,6,8–10,17,20', 'Background Vocals'],
#  ['2,5,6,8–10,17,20', 'Holly Laessig'],
#  ['Vibraphone', 'Mellotron', '5,6,11–13,16', 'Scott McCaughey', 'Typewriter'],
#  ['Summerteeth', 'summerteeth', 'Wilco', 'Reprise Records'],
#  ['Summerteeth', 'Pro Tools'],
#  ['Tweedy', 'Jay Bennett'],
#  ['The Village Voice', 'AllMusic', 'the Chicago Tribune'],
#  ['Wilco', 'David Kahne'],
#  ['Summerteeth', 'Spicewood', 'Texas', 'Willie Nelson'],
#  ['William H. Gass', 'Tweedy', 'John Fante', 'Henry Miller'],
#  ['Tweedy', 'Sue Miller'],
#  ['Miller', 'Tweedy'],
#  ['Billy Bragg', 'Wilco'],
#  ['Summerteeth',
#   'Dave Trumfio',
#   'Mike Hagler',
#   'Chicago',
#   'Kingsize Soundlabs',
#   'Wilco'],
#  ['Tweedy', 'Bennett'],
#  ['Tweedy', 'Mellotron', 'Jay Bennett'],
#  ['Ken Coomer', 'John Stirratt', 'Bennett'],
#  ['John', 'Coomer'],
#  ['Jeff', 'Jay'],
#  ['Pitchfork', 'Pazz & Jop'],
#  ['Jason Ankeny', 'AllMusic'],
#  ['Bennett', 'Wilco', 'Neil Lieberman', 'Pitchfork'],
#  ['Greg Kot', 'The Chicago Tribune'],
#  ['Jeff Tweedy', 'Jay Bennett'],
#  ['Tweedy', 'John Stirratt', 'Stirratt', 'Bennett'],
#  ['Tweedy', 'Stirratt', 'Bennett'],
#  ['Tweedy', 'Stirratt', 'Bennett'],
#  ['Sum', 'Arizona'],
#  ['Farfisa', '4–8', 'Jay Bennett', '3–9', 'Jeff Tweedy'],
#  ['6–14', 'John Stirratt', 'Ken Coomer', '4–8'],
#  ['Mark Greenberg', 'Leroy Bach', 'Dave Crawford'],
#  ['Lawrence Azerrad',
#   'Jim Scott',
#   'David Campbell',
#   'House',
#   'String',
#   'David Kahne',
#   'Mike Hagler',
#   'Larry Greenhill',
#   'Russ Long',
#   'Mike Scotella',
#   'Steve Chadie',
#   'Chris Grainger',
#   'David Trumfio',
#   'Mitch Easter'],
#  ['Summerteeth', 'Jo Nesbø'],
#  ['Broadway Books', 'New York City', 'New York'],
#  ['Spencer', 'Salon', 'Tweedy', 'Wilco', 'Jeff Tweedy'],
#  ['Tweedy', 'Sukierae', 'Spencer'],
#  ['Jeff', 'Susie', 'Spencer'],
#  ['Cunningham',
#   'Darin Gray',
#   'Liam Kazar',
#   'Tweedy',
#   'Liam',
#   'Sima Cunningham',
#   "Mavis Staples'",
#   'Jeff Tweedy',
#   'Jim Elkington'],
#  ['Marrow', 'Tweedy', 'Liam Kazar', 'Dorian Gehring', 'Spencer Tweedy'],
#  ['Sima Cunningham',
#   'Milwaukee',
#   'Sullivan Davis',
#   'Chicago',
#   'Wisconsin',
#   'Andrew Sa',
#   'Cosmic Country Showcase',
#   'Kazar'],
#  ['Illinois', 'Belleville', 'Tupelo'],
#  ['Jay Farrar', 'Jeff Tweedy', 'Mike Heidorn'],
#  ['Rockville Records', 'Sire Records'],
#  ['Farrar', 'Wilco'],
#  ['Hank Williams', 'the Carter Family', 'Tupelo'],
#  ['Tweedy', 'Farrar', 'Belleville'],
#  ['Jay Farrar', 'Wade', 'Plebes', 'Dade'],
#  ['Belleville', 'Plebes', 'Illinois'],
#  ['Jay Farrar', 'Jeff Tweedy'],
#  ['Tweedy', 'Plebes'],
#  ['Tweedy', 'Dade Farrar'],
#  ['Mike Heidorn', 'Dade Farrar'],
#  ['psychedelic rock group', 'Plebes', 'Groupies'],
#  ['Millstadt', 'Jo Ann', 'Tweedy', 'Illinois'],
#  ['Snowmonkeys',
#   'Sammy',
#   'Belleville',
#   'B St Bar',
#   'Charlie Langrehr',
#   'Newsboys'],
#  ['Wade Farrar', 'Southern Illinois University', 'the United States Army'],
#  ['Heidorn', 'Jay Farrar', 'Tweedy'],
#  ['Tweedy', 'Tony Mayr'],
#  ['Chuck Wagner', 'Tupelo'],
#  ['Elvis', 'Wagner'],
#  ['Warren Zevon', 'Johnny Thunders'],
#  ['St. Louis', 'Tweedy', 'Tony Margherita'],
#  ['Cicero', 'Washington University', 'St. Louis', 'Tupelo'],
#  ['Chicken Truck', 'Brian Henneman'],
#  ['Matt Allison', 'Illinois', 'Chicago', 'Champaign', 'Tupelo'],
#  ['The CMJ New Music Report', 'Tupelo'],
#  ['New York City',
#   'Debbie Southwood-Smith',
#   'Jay Fialkov',
#   'CBGB',
#   'Giant Records'],
#  ['Giant Records', 'Rockville Records', 'Tupelo'],
#  ['Boston', 'Massachusetts', 'Rockville'],
#  ['Sean Slade', 'Dinosaur Jr.', 'Paul Kolderie'],
#  ['Gibson Les Paul SG Junior', 'Farrar', 'J. Mascis'],
#  ['Farrar',
#   'Heidorn',
#   'Brian Henneman',
#   'Coffee Creek',
#   'The Bottle Rockets',
#   'Tweedy'],
#  ['Uncle Tupelo', 'Henneman'],
#  ['Heidorn', 'Farrar', 'Tweedy'],
#  ['Farrar', 'Tweedy', 'Sue Miller'],
#  ['Massachusetts', 'North Brookfield', 'Long View Farm'],
#  ['Slade',
#   'Enormous Richard',
#   'Henneman',
#   'Gary Louris',
#   'Chris Bess',
#   'Rich Gilbert',
#   'Kolderie'],
#  ['Slade', 'Kolderie'],
#  ['Michelle Shocked', 'Arkansas Traveler', 'Taj Mahal', 'Uncle Tupelo'],
#  ['Nirvana', 'Tupelo'],
#  ['Georgia', 'Watt Club', 'Athens', 'Peter Buck'],
#  ['Uncle', 'Tupelo'],
#  ['Joe McEwen', 'Sire Records'],
#  ['Dinosaur Jr.', 'McEwen', 'Shawn Colvin'],
#  ['McEwen', 'Uncle Tupelo', 'Gary Louris'],
#  ['Tony Margherita', 'Rockville'],
#  ['Belleville', 'Mike Heidorn'],
#  ['Belleville', 'Heidorn', 'Ken Coomer', 'Bill Belzer', 'Tupelo'],
#  ['Tweedy', 'Farrar', 'Coomer'],
#  ['Heidorn', 'Belzer'],
#  ['Belzer', 'Tweedy'],
#  ['Sugar', 'Belzer', 'Coomer'],
#  ['Michelle Shocked',
#   'John Stirratt',
#   'Brian Henneman',
#   'The Bottle Rockets',
#   'Max Johnston'],
#  ['Tweedy', 'Stirratt'],
#  ['Texas', 'Austin', 'Uncle Tupelo'],
#  ['Douglas Quintet', 'Farrar', 'Doug Sahm'],
#  ['Creedence Clearwater Revival', 'the Red Hot Organization', 'Effigy'],
#  ['Tweedy', 'Anodyne, Farrar and', 'Stirratt, Coomer', 'Johnston'],
#  ['Farrar', 'Tweedy'],
#  ['Farrar', 'Tweedy'],
#  ['Tweedy', 'Farrar'],
#  ['Farrar', 'Tony Margherita'],
#  ['Tweedy', 'Farrar', 'Margherita'],
#  ['Jeff', 'Farrar'],
#  ['Farrar', 'Tweedy', 'Margherita'],
#  ['Farrar', 'Tupelo', 'Margherita'],
#  ['Farrar', 'Tweedy'],
#  ['Tweedy', 'Farrar'],
#  ['Columbia', 'St. Louis', 'Missouri', 'Tupelo'],
#  ['St. Louis', 'the Riverfront Times'],
#  ['Farrar', 'Tweedy', 'Mike Heidorn'],
#  ['Farrar', 'Tweedy', 'Tupelo'],
#  ['Uncle', 'Tweedy', 'Wilco', 'Tupelo'],
#  ['Farrar', 'Jim Boquist', 'Joe Henry', 'Son Volt', 'Boquist', 'Tupelo'],
#  ['Farrar', 'Belleville', 'Dave', 'Boquist', 'Mike Heidorn'],
#  ['Farrar', 'Trace', 'Warner Bros. Records', 'Volt', 'Reprise Records'],
#  ['Trace', 'Wilco'],
#  ['Mike Heidorn', 'PopMatters'],
#  ['Tweedy', 'Farrar'],
#  ['Farrar',
#   'Barry Tenenbaum',
#   'Dutch East India Trading',
#   'Tweedy',
#   'Rockville Records',
#   'Tenenbaum',
#   'Tupelo'],
#  ['Farrar', 'Tweedy'],
#  ['St. Louis', 'Belleville'],
#  ['Jack Kerouac', 'Farrar', 'Kurt Vonnegut'],
#  ['Tweedy', 'Farrar', 'Heidorn'],
#  ['the St. Louis Post-Dispatch', 'Jeff Tweedy'],
#  ['Hank Williams', 'Dinosaur Jr.', 'Bob Dylan', 'Black Flag'],
#  ['Tweedy', 'Boon', 'D. Boon'],
#  ['Creedence Clearwater Revival', 'Texas Tornados', 'The Louvin Brothers'],
#  ['the Beach and', 'Neil Young', 'Harvest'],
#  ['Michael Corcoran', 'Bob'],
#  ['Lyle Lovett', 'Tupelo'],
#  ['Heidorn', 'Farrar', 'Tweedy'],
#  ['Tupelo', 'Country Standard Time'],
#  ['the Flying Burrito Brothers', 'Woody Guthrie'],
#  ['Tupelo', 'Belleville', 'IL'],
#  ['Robbie Fulks', 'Shelby Lynne'],
#  ['Bill Belzer', 'Mike Heidorn', 'Jeff Tweedy'],
#  ['Max Johnston', 'John Stirratt'],
#  ['Tupelo', 'Legacy Records'],
#  ['Farrar, Tweedy', 'Lauren Frey'],
#  ['Nashville', 'Dowling Press', 'TN'],
#  ['Greg', 'Kot'],
#  ['Broadway Books', 'NY', 'New York City'],
#  ['Chicago',
#   'Tupelo Archives\nPostcard From Hell Mailing List',
#   'Wilco',
#   'Illinois'],
#  ['Jay Farrar', 'Tupelo'],
#  ['John Stirratt', 'Wilco', 'Jeff Tweedy'],
#  ['Glenn Kotche',
#   'Tweedy',
#   'Stirratt',
#   'Mikael Jorgensen',
#   'Pat Sansone',
#   'Nels Cline'],
#  ['Billy Bragg', 'Wilco'],
#  ['Wilco', 'Beatles', 'Bill Fay'],
#  ['Wilco', 'Yankee Hotel Foxtrot'],
#  ['Wilco', 'Reprise Records'],
#  ['Wilco', 'Foxtrot', 'Nonesuch Records'],
#  ['Wilco', 'Yankee Hotel Foxtrot'],
#  ['Best Alternative Music Album', 'Wilco'],
#  ['Wilco', 'Cruel Country'],
#  ['Wilco', 'Tupelo'],
#  ['Jay Farrar', 'Jeff Tweedy'],
#  ['Farrar', 'Tweedy'],
#  ['Uncle',
#   'Farrar',
#   'John Stirratt',
#   'Max Johnston',
#   'Tweedy',
#   'Ken Coomer',
#   'Tupelo'],
#  ['Uncle', 'Brian Henneman', 'Tupelo', 'Wilco', 'the Bottle Rockets'],
#  ['Tweedy', 'Wilco'],
#  ['Syd Straw', 'Easley', 'the Red Hot Organization', 'Ernest Tubb', 'Wilco'],
#  ['Warner Brothers', 'Tweedy', 'Reprise Records'],
#  ['Tweedy', 'Tupelo'],
#  ['John Stirratt', 'Tweedy'],
#  ['Tweedy', 'Wilco'],
#  ['Tweedy', 'Tupelo'],
#  ['Jay Farrar', 'Billboard Heatseekers', 'Son Volt'],
#  ['the Village Voice', 'Pazz & Jop'],
#  ['St. Louis', 'Tweedy', 'Missouri', 'Cicero', 'Wilco'],
#  ['Ken Coomer', 'Jeff'],
#  ['Arizona', 'Wilco'],
#  ['Wilco', 'Peter Sellers'],
#  ['Max Johnston', 'Jesse Greene', 'Bennett', 'Johnston'],
#  ['Freakwater', 'Bob Egan'],
#  ['Tweedy', 'Reprise Records'],
#  ['the Pazz & Jop Critics Poll', 'Billboard'],
#  ['the Modern Rock Tracks', 'Billboard'],
#  ['Texas', 'Summerteeth', 'Willie Nelson', 'Spicewood', 'Wilco'],
#  ['Tweedy', 'Bennett'],
#  ['Nora Guthrie', 'Billy Bragg', 'Woody Guthrie'],
#  ['Guthrie', 'Huntington'],
#  ['Nora', 'Woody Guthrie', 'MTV'],
#  ['Nora', 'Bragg', 'Woody'],
#  ['Guthrie', 'Bragg'],
#  ['Tweedy', 'Wilco', 'Bragg', 'Bennett'],
#  ['Titanic Love Affair', 'Billy Bragg', 'Tweedy', 'Bennett'],
#  ['Bush Empire', 'Wilco', 'Shepherd', 'Bragg'],
#  ['Guthrie', 'Tweedy', 'Bragg'],
#  ['Wilco', 'Bragg'],
#  ['Wilco', 'Bragg', 'Bennett'],
#  ['Bragg', 'Bennett'],
#  ['Chicago', 'Bragg', 'Bennett'],
#  ['Rolling Stone', 'Robert Christgau'],
#  ['Bob Egan', 'Leroy Bach'],
#  ['Summerteeth', 'Spicewood', 'Wilco'],
#  ['Uncle', 'Pro Tools', 'Wilco', 'Tupelo'],
#  ['Stirratt', 'Coomer'],
#  ['Summerteeth', 'Mellotron', 'Jay', 'Stirratt'],
#  ['Time Inc.', 'Warner Communications', 'Warner Brothers'],
#  ['Summerteeth', 'Howie Klein', 'Wilco'],
#  ['Klein', 'A&R', 'Reprise'],
#  ['A&R', 'Wilco', 'David Kahne'],
#  ['Summerteeth', 'Pazz & Jop'],
#  ['Chicago', 'Wilco'],
#  ["O'Rourke", 'Chicago', 'Tweedy', "Jim O'Rourke", 'Jeff Tweedy'],
#  ['Glenn Kotche', 'Tweedy', 'Loose Fur', "O'Rourke"],
#  ['Tweedy', 'Wilco'],
#  ['Tweedy', 'Kotche', 'Loose Fur'],
#  ['Loose Fur',
#   'Yankee Hotel Foxtrot',
#   "O'Rourke",
#   'Tweedy',
#   'Kotche',
#   'Ken Coomer',
#   'Wilco',
#   'Bennett'],
#  ['Tweedy', 'Bennett'],
#  ['Tweedy', 'Bennett', "O'Rourke"],
#  ['Loose Fur', "O'Rourke"],
#  ['Sam Jones', 'Wilco'],
#  ['Warner', 'America Online', 'Time Warner', 'Warner Bros. Records'],
#  ['Warner Music Group', 'Howie Klein', 'Reprise Records'],
#  ['Klein', 'David Kahne'],
#  ['Kahne', 'Yankee Hotel Foxtrot'],
#  ['Wilco', 'Greg Kot', 'Vukovic'],
#  ['Greg Kot', 'Yankee Hotel Foxtrot'],
#  ['Wilco', 'Warner/Reprise Records'],
#  ['Wilco', 'Wayne Coyne'],
#  ['Warners', 'Wilco'],
#  ['Time Warner', 'Nonesuch Records'],
#  ['Wilco', 'Yankee Hotel Foxtrot'],
#  ['Q Magazine', 'Yankee Hotel Foxtrot', 'Pazz & Jop'],
#  ['Chicago', 'Wilco', 'Scott McCaughey', 'Yankee Hotel Foxtrot'],
#  ['Wilco', 'McCaughey'],
#  ['Wilco', 'Bill Fay'],
#  ['Wilco', 'Mikael Jorgensen', 'Down'],
#  ['Wilco', 'New York City'],
#  ['Wilco', 'Foxtrot', "Jim O'Rourke", 'Loose Fur'],
#  ['Summerteeth', 'Pro Tools', 'Yankee Hotel Foxtrot'],
#  ['Chicago', 'Leroy Bach'],
#  ['Wilco', 'Yankee Hotel Foxtrot'],
#  ['Bach', 'The Autumn Defense', 'Pat Sansone', 'Nels Cline', 'Wilco'],
#  ['Chicago', 'Tweedy'],
#  ['Wilco', 'U.S.'],
#  ['Chicago Tribune', 'Greg Kot', 'Wilco'],
#  ['Chicago', 'Wilco', 'The Vic Theater'],
#  ['Entertainment Weekly', 'Spin, Billboard'],
#  ['Chicago', 'Wilco'],
#  ['The Byrds and Fairport Convention', 'Sky Blue Sky'],
#  ['Wilco', 'Volkswagen'],
#  ['Telefónica Móviles (Movistar', 'Wilco', 'Apple Inc.'],
#  ['Sky Blue Sky', 'Wilco', 'James Brubaker'],
#  ['Wilco', 'Hernandez'],
#  ['Locke', 'Hernandez'],
#  ['Fleet Foxes', 'Wilco', 'US', 'Bob Dylan'],
#  ['John Stirratt',
#   'Liam Finn',
#   'The Sun Came Out',
#   'Johnny Marr',
#   'Lisa Germano',
#   'Auckland,',
#   "Ed O'Brien",
#   'Phil Selway',
#   'Pat Sansone',
#   'Glenn Kotche',
#   'New Zealand',
#   'Jeff Tweedy',
#   'Neil Finn'],
#  ['John', 'Johnny Marr', 'Pat', 'Glenn', 'Jeff Tweedy'],
#  ['Auckland', 'New Zealand', 'Roundhead Studios', 'Finn'],
#  ['Wilco', 'Jim Scott', 'Neil Finn'],
#  ['Nels Cline', 'Chicago', 'Mikael Jorgensen'],
#  ['Wilco', 'U.S.'],
#  ['Guthrie', 'Nora', 'Wilco'],
#  ['Urbana', 'Jay Bennett', 'Illinois'],
#  ['Jeff Tweedy', 'Bennett'],
#  ['Wilco', 'David Letterman', 'Feist'],
#  ['Skip Spence', 'James Gadson', 'Jamie Lidell', 'Feist', 'Beck', 'Wilco'],
#  ['Boston', 'North Adams', 'Wilco', 'Massachusetts'],
#  ['Pronto',
#   'the Massachusetts Museum of Contemporary Art',
#   'The Autumn Defense',
#   'Wilco',
#   'Jeff Tweedy',
#   'The Nels Cline Singers'],
#  ['Cherry', 'Richard Bishop', 'The Books', 'Avi Buffalo', 'Mavis Staples'],
#  ['the Bread and Puppet Theater',
#   'Todd Barry',
#   'Kristen Schaal',
#   'Hannibal Buress',
#   'Kotche',
#   'John Mulaney',
#   'Cline'],
#  ['The Netherlands', 'Utrecht'],
#  ['The Cairo Gang',
#   'Fennesz',
#   'Tortoise',
#   'Lee Ranaldo',
#   'Steve Gunn',
#   'William Tyler',
#   'Bassekou Kouyaté'],
#  ['dBpm Records',
#   'Tony Margherita',
#   'Twitter',
#   'Massachusetts',
#   'Easthampton',
#   'Wilco'],
#  ['MassMoca', 'Wilco'],
#  ['Wilco', 'US'],
#  ['Wilco', 'Josh Modell', 'Metacritic'],
#  ['Bandcamp', 'SPLC', 'Tweedy', 'Robert', 'Wilco'],
#  ['Tweedy', 'Barack Obama'],
#  ['Miiri', 'Finland', 'Glenn Kotche', 'Wilco', 'Fulbright'],
#  ['Sleater-Kinney', 'Wilco'],
#  ['Sleater-Kinney', 'Wilco'],
#  ['the Austin City Limits Hall of Fame', 'Wilco', 'World Central Kitchen'],
#  ['Tweedy', 'George Floyd'],
#  ['Wilco', 'Bennett'],
#  ['Chicago', 'Fred Uhter', 'Gorman Bechard', 'Bennett'],
#  ['Summerteeth', 'Wilco', 'Yankee Hotel Foxtrot'],
#  ['Bechard', 'Uhter'],
#  ['Wilco', 'Bennett'],
#  ['Yankee Hotel Foxtrot',
#   'Jay Bennett',
#   "Sam Jones'",
#   'Jeff Tweedy',
#   'Bennett'],
#  ['Fred Uhter', 'Gorman Bechard', 'Jay Bennett'],
#  ['Tweedy', 'Bennett'],
#  ['Lennon', 'McCartney'],
#  ['Neil Young', 'Tweedy', 'Brian Wilson', 'John Lennon'],
#  ['Tweedy', 'Richard Lloyd of Television'],
#  ['Wilco', 'Jason & the Scorchers', 'Tupelo'],
#  ['Derek Bailey',
#   'Ornette Coleman',
#   'Albert Ayler',
#   "O'Rourke",
#   'Tweedy',
#   'Miles Davis',
#   'John Coltrane'],
#  ['Wilco', 'cadavre exquis'],
#  ['William H. Gass', 'Tropic of Cancer', 'Henry Miller', 'Harold Bloom'],
#  ['the New York Times', 'Wilco'],
#  ['the Beach Boys', 'Band'],
#  ['America', 'Wilco', 'Stone'],
#  ['Derek Webb', 'Caedmon', 'Grace Potter', 'National', 'Wilco'],
#  ['Adam Grunduciel', 'Wilco', 'The War on Drugs'],
#  ['Wilco', 'Counting Crows', 'Norah Jones'],
#  ['Broadway Books', 'New York'],
#  ['Joe', '0-7679', 'Levy'],
#  ['Wenner Books', 'New York'],
#  ['Wilco', 'Curlie\nWilco'],
#  ['Reprise Records', 'Tupelo'],
#  ['Yankee Hotel Foxtrot', 'the Chicago Tribune'],
#  ['Nonesuch Records', 'Warner Bros. Records'],
#  ['Billy Bragg', 'Wilco', 'Woody Guthrie', 'Down'],
#  ['the Recording Industry Association of America',
#   'RIAA',
#   'Yankee Hotel Foxtrot'],
#  ['Wilco', 'Mike Foxtrot'],
#  ['Syd Straw', 'Wilco'],
#  ['Greg', 'Kot', 'Jeff Tweedy', 'Tupelo'],
#  ['Broadway Books', 'NY', 'New York City'],
#  ['Wilco', 'AllMusic\n\nYankee Hotel Foxtrot', 'Discogs\nWilco'],
#  ['Glenn Kotche', 'Wilco', 'Jay Bennett', 'Reprise Records'],
#  ['Wilco', 'Nonesuch Records'],
#  ['Chicago', 'Wilco', 'Jeff Tweedy'],
#  ['Tweedy', "Jim O'Rourke"],
#  ['Tweedy', "O'Rourke"],
#  ['Tweedy', "O'Rourke"],
#  ['Glenn Kotche', "O'Rourke"],
#  ['Tweedy', 'Coomer'],
#  ['Kotche', 'Tweedy', 'Wilco', 'Coomer'],
#  ['Jay Bennett',
#   "O'Rourke",
#   'Chris Brickley',
#   'Tweedy',
#   'the Chicago Recording Company'],
#  ['Tweedy', 'Bennett'],
#  ['Tweedy', 'Bennett'],
#  ['Tweedy', "Jim O'Rourke"],
#  ['Wilco', "Jim O'Rourke"],
#  ['Tweedy', 'Bennett'],
#  ['Numbers Station', 'Wilco'],
#  ['Sam Jones', 'Wilco', 'Los Angeles'],
#  ['Wilco', 'Coomer'],
#  ['AOL Time Warner', 'AOL', 'Time Warner'],
#  ['Howie Klein', 'Wilco', 'Reprise Records'],
#  ['Klein', 'A&R', 'David Kahne'],
#  ['A&R', 'Kahne', 'Mio Vukovic'],
#  ['Josh Grier', 'Wilco'],
#  ['Wilco', 'Yankee Hotel Foxtrot'],
#  ['Wilco', 'the Chicago Tribune'],
#  ['Tweedy', 'Wilco'],
#  ['Wilco', 'Warner Music', 'Nonesuch Records'],
#  ['Records', 'Yankee Hotel Foxtrot', 'Warner', 'Wilco', 'Reprise Records'],
#  ['Wilco', 'Yankee Hotel Foxtrot'],
#  ['Chicago', 'Wilco', 'New York City', 'the Auditorium Theater'],
#  ['Brent Sirota', 'Pitchfork'],
#  ['Zac Johnson', 'Rolling Stone', 'David Fricke'],
#  ['Stylus Magazine', 'Wilco'],
#  ['Americana', 'Kid A.', 'YHF'],
#  ['Press', 'UK', 'Tweedy', "Jim O'Rourke", 'Wilco'],
#  ['the World Trade Center', 'Jeff Gordinier', 'Entertainment Weekly'],
#  ['Recordings', 'Rolling Stone', 'Tom Moon'],
#  ['Wilco', 'Rolling Stone'],
#  ['Joe',
#   'Wenner Books Retrieved',
#   'New York',
#   'Broadway Books',
#   'Greg',
#   'Wilco']]

# %%
network_df = get_network_data(entities) 

network_df.head()
# Out:
#             source            target
# 0            Wilco       Jeff Tweedy
# 1    Rolling Stone        PopMatters
# 2  Reprise Records             Wilco
# 3  Reprise Records  Nonesuch Records
# 4    Rolling Stone           Foxtrot

# %%
G = nx.from_pandas_edgelist(network_df)

# %%
print(G)
# Out:
# Graph with 924 nodes and 1403 edges

# %%
draw_graph(G, show_names=False, node_size=1, edge_width=0.3)

# %% [markdown]
# # Inspect the Core

# %%
# draw the core

draw_graph(nx.k_core(G, 6), node_size=4, font_size=11, show_names=True, edge_width=0.3)

# %% [markdown]
# # Important Nodes

# %%
page_rank = nx.pagerank(G)

pr_df = pd.DataFrame().from_dict(page_rank, orient='index')
pr_df.columns = ['page_rank']
pr_df.sort_values('page_rank', ascending=False, inplace=True)
pr_df.head(10)
# Out:
#                page_rank
# Wilco           0.045149
# Tweedy          0.032668
# Billy Bragg     0.012965
# John Stirratt   0.012769
# Farrar          0.011782
# Glenn Kotche    0.011065
# Jim Scott       0.010039
# Jeff Tweedy     0.010023
# Chicago         0.009920
# Tupelo          0.008576

# %%
title = 'Important Entities by PageRank'

pr_df.head(20).plot.barh(figsize=(12,8), title=title).invert_yaxis()

# %%
betw_cent = nx.betweenness_centrality(G)

betw_cent_df = pd.DataFrame().from_dict(betw_cent, orient='index')
betw_cent_df.columns = ['betweenness_centrality']
betw_cent_df.sort_values('betweenness_centrality', ascending=False, inplace=True)
betw_cent_df.head(10)
# Out:
#                betweenness_centrality
# Wilco                        0.340473
# Tweedy                       0.251926
# John Stirratt                0.069083
# Billy Bragg                  0.066455
# Jeff Tweedy                  0.053261
# Glenn Kotche                 0.052650
# Farrar                       0.051946
# Chicago                      0.041757
# Jim Scott                    0.039689
# Tupelo                       0.038313

# %%
title = 'Important Entities by Betweenness Centrality'

betw_cent_df.head(20).plot.barh(figsize=(12,8), title=title).invert_yaxis()

# %% [markdown]
# # So Much More
#
# There's so much more we can do. Look through previous days and think about some of our options. For instance, we might want to understand the shortest path between certain entities, or we might want to look at the communities that are part of this network. This is a completely different kind of network, as this was built entirely off of text, using Machine Learning, using Named Entity Recognition. This is covered in my book. Today's code came from my book's Github.
#
# Also, remember, this is just one field, the 'content' field. We can also create networks using websites as we have the 'web_links' data. There are multiple different networks that can be built using this data.

# %%
net_df = nx.to_pandas_edgelist(G)
net_df.head()
# Out:
#   source           target
# 0  Wilco      Jeff Tweedy
# 1  Wilco  Reprise Records
# 2  Wilco          Foxtrot
# 3  Wilco     Jim O'Rourke
# 4  Wilco        Loose Fur

# %%
outfile = r'data/wilco_content_edgelist.csv'

net_df.to_csv(outfile, index=False)
